# %%
import numpy as np
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-398867a4-affc-4600-964a-67d060d44e0b" name="files[]" multiple disabled />
#      <output id="result-398867a4-affc-4600-964a-67d060d44e0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data14smaller_0.csv to data14smaller_0 (1).csv

# %%
data18smaller = pd.read_csv("data14smaller_0.csv", low_memory = False, dtype = {'subsidies_flag':"int64"})

# %%
# !pip install pgmpy==0.1.7
from pgmpy.estimators import HillClimbSearch, BicScore, BayesianEstimator
from pgmpy.models import BayesianModel
from sklearn.model_selection import train_test_split
from pgmpy.inference import VariableElimination
# Out:
# Collecting pgmpy==0.1.7
#   Downloading https://files.pythonhosted.org/packages/98/dc/2cde83edf1e3b52407c9a106446708c31b0380bb832d3e472c853f3dd069/pgmpy-0.1.7.tar.gz (219kB)
#      |████████████████████████████████| 225kB 2.9MB/s
# Collecting networkx<1.12,>=1.11 (from pgmpy==0.1.7)
#   Downloading https://files.pythonhosted.org/packages/d3/2c/e473e54afc9fae58dfa97066ef6709a7e35a1dd1c28c5a3842989322be00/networkx-1.11-py2.py3-none-any.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 43.4MB/s
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python2.7/dist-packages (from pgmpy==0.1.7) (1.2.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python2.7/dist-packages (from pgmpy==0.1.7) (1.16.3)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python2.7/dist-packages (from networkx<1.12,>=1.11->pgmpy==0.1.7) (4.4.0)
# Building wheels for collected packages: pgmpy
#   Building wheel for pgmpy (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/27/d5/45/f9bd7e0f7d3752b706163ce2a0333d29855828c3e57a003640
# Successfully built pgmpy
# Installing collected packages: networkx, pgmpy
#   Found existing installation: networkx 2.2
#     Uninstalling networkx-2.2:
#       Successfully uninstalled networkx-2.2
# Successfully installed networkx-1.11 pgmpy-0.1.7

# %%
data18train, data18test = train_test_split(data18smaller,random_state=9,test_size=0.2)
hc = HillClimbSearch(data18train, scoring_method=BicScore(data18train))
best_model = hc.estimate()
print(best_model.edges())
# Out:
# [('bldgclass', 'subsidies_flag'), ('bldgclass', 'ownertype'), ('bldgclass', 'residfar'), ('bldgclass', 'yearbuilt'), ('bldgclass', 'violations'), ('bldgclass', 'landuse'), ('residfar', 'violations'), ('residfar', 'subsidies_flag'), ('violations', 'yearbuilt'), ('violations', 'subsidies_flag'), ('violations', 'ownertype'), ('violations', 'unitsres'), ('landuse', 'residfar'), ('landuse', 'violations'), ('landuse', 'unitsres')]

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')

for cpd in best_model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
    
print best_model.local_independencies('violations')

for thenode in best_model.nodes():
    print best_model.active_trail_nodes(thenode)
# Out:
# CPD of unitsres:
# +-------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+
# | landuse     | landuse(0)             | landuse(0)             | landuse(1)             | landuse(1)            | landuse(2)            | landuse(2)             | landuse(3)             | landuse(3)            |
# +-------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+
# | violations  | violations(0)          | violations(1)          | violations(0)          | violations(1)         | violations(0)         | violations(1)          | violations(0)          | violations(1)         |
# +-------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+
# | unitsres(0) | 0.9999549239905791     | 0.9987129987129987     | 0.9999500524449328     | 0.9997130353683908    | 0.9942922374429224    | 0.9556681443951869     | 0.9995694665690791     | 0.9938092474366416    |
# +-------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+
# | unitsres(1) | 1.1269002355221492e-05 | 0.00032175032175032174 | 1.2486888766794866e-05 | 7.174115790228854e-05 | 0.001997716894977169  | 0.026810217437196537   | 4.3053343092091103e-05 | 0.0001934610176049526 |
# +-------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+
# | unitsres(2) | 1.1269002355221492e-05 | 0.00032175032175032174 | 1.2486888766794866e-05 | 7.174115790228854e-05 | 0.0007134703196347032 | 0.004644289634789952   | 4.3053343092091103e-05 | 0.0001934610176049526 |
# +-------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+
# | unitsres(3) | 1.1269002355221492e-05 | 0.00032175032175032174 | 1.2486888766794866e-05 | 7.174115790228854e-05 | 0.001997716894977169  | 0.00021110407430863416 | 0.0003013734016446377  | 0.005610369510543625  |
# +-------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+
# | unitsres(4) | 1.1269002355221492e-05 | 0.00032175032175032174 | 1.2486888766794866e-05 | 7.174115790228854e-05 | 0.0009988584474885844 | 0.01266624445851805    | 4.3053343092091103e-05 | 0.0001934610176049526 |
# +-------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+
# CPD of bldgclass:
# +--------------+-----------+
# | bldgclass(0) | 0.110817  |
# +--------------+-----------+
# | bldgclass(1) | 0.295592  |
# +--------------+-----------+
# | bldgclass(2) | 0.428008  |
# +--------------+-----------+
# | bldgclass(3) | 0.0582847 |
# +--------------+-----------+
# | bldgclass(4) | 0.0209889 |
# +--------------+-----------+
# | bldgclass(5) | 0.0863097 |
# +--------------+-----------+
# CPD of subsidies_flag:
# +-------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+---------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+--------------------+----------------------+---------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+------------------------+---------------------+-----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+----------------------+----------------------+---------------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+---------------------+-----------------------+----------------------+
# | bldgclass         | bldgclass(0)          | bldgclass(0)          | bldgclass(0)          | bldgclass(0)         | bldgclass(0)         | bldgclass(0)  | bldgclass(0)         | bldgclass(0)  | bldgclass(1)          | bldgclass(1)          | bldgclass(1)          | bldgclass(1)          | bldgclass(1)         | bldgclass(1)       | bldgclass(1)         | bldgclass(1)  | bldgclass(2)          | bldgclass(2)        | bldgclass(2)          | bldgclass(2)        | bldgclass(2)          | bldgclass(2)        | bldgclass(2)          | bldgclass(2)        | bldgclass(3)          | bldgclass(3)        | bldgclass(3)           | bldgclass(3)        | bldgclass(3)          | bldgclass(3)        | bldgclass(3)         | bldgclass(3)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)         | bldgclass(4)         | bldgclass(4)         | bldgclass(4)        | bldgclass(5)           | bldgclass(5)          | bldgclass(5)           | bldgclass(5)         | bldgclass(5)          | bldgclass(5)        | bldgclass(5)          | bldgclass(5)         |
# +-------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+---------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+--------------------+----------------------+---------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+------------------------+---------------------+-----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+----------------------+----------------------+---------------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+---------------------+-----------------------+----------------------+
# | residfar          | residfar(0)           | residfar(0)           | residfar(1)           | residfar(1)          | residfar(2)          | residfar(2)   | residfar(3)          | residfar(3)   | residfar(0)           | residfar(0)           | residfar(1)           | residfar(1)           | residfar(2)          | residfar(2)        | residfar(3)          | residfar(3)   | residfar(0)           | residfar(0)         | residfar(1)           | residfar(1)         | residfar(2)           | residfar(2)         | residfar(3)           | residfar(3)         | residfar(0)           | residfar(0)         | residfar(1)            | residfar(1)         | residfar(2)           | residfar(2)         | residfar(3)          | residfar(3)         | residfar(0)          | residfar(0)         | residfar(1)          | residfar(1)         | residfar(2)          | residfar(2)          | residfar(3)          | residfar(3)         | residfar(0)            | residfar(0)           | residfar(1)            | residfar(1)          | residfar(2)           | residfar(2)         | residfar(3)           | residfar(3)          |
# +-------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+---------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+--------------------+----------------------+---------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+------------------------+---------------------+-----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+----------------------+----------------------+---------------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+---------------------+-----------------------+----------------------+
# | violations        | violations(0)         | violations(1)         | violations(0)         | violations(1)        | violations(0)        | violations(1) | violations(0)        | violations(1) | violations(0)         | violations(1)         | violations(0)         | violations(1)         | violations(0)        | violations(1)      | violations(0)        | violations(1) | violations(0)         | violations(1)       | violations(0)         | violations(1)       | violations(0)         | violations(1)       | violations(0)         | violations(1)       | violations(0)         | violations(1)       | violations(0)          | violations(1)       | violations(0)         | violations(1)       | violations(0)        | violations(1)       | violations(0)        | violations(1)       | violations(0)        | violations(1)       | violations(0)        | violations(1)        | violations(0)        | violations(1)       | violations(0)          | violations(1)         | violations(0)          | violations(1)        | violations(0)         | violations(1)       | violations(0)         | violations(1)        |
# +-------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+---------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+--------------------+----------------------+---------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+------------------------+---------------------+-----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+----------------------+----------------------+---------------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+---------------------+-----------------------+----------------------+

# +-------------+-----------------------+--------------+--------------+--------------+------------------------+--------------+--------------+--------------+--------------+----------------------+--------------+---------------------+--------------+--------------+---------------------+---------------------+--------------+----------------------+---------------------+---------------------+--------------+--------------+--------------+----------------------+
# | residfar(3) | 0.0022359752445597924 | 0.25         | 0.25         | 0.25         | 0.00031437125748502996 | 0.25         | 0.25         | 0.25         | 0.25         | 0.005641373030239092 | 0.25         | 0.12578616352201258 | 0.25         | 0.25         | 0.10111131353616323 | 0.2059090909090909  | 0.25         | 0.005035246727089627 | 0.07581699346405228 | 0.11764705882352941 | 0.25         | 0.25         | 0.25         | 0.029374070846362843 |
# +-------------+-----------------------+--------------+--------------+--------------+------------------------+--------------+--------------+--------------+--------------+----------------------+--------------+---------------------+--------------+--------------+---------------------+---------------------+--------------+----------------------+---------------------+---------------------+--------------+--------------+--------------+----------------------+
# CPD of yearbuilt:
# +--------------+------------------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+----------------------+------------------------+----------------------+----------------------+-----------------------+-----------------------+
# | bldgclass    | bldgclass(0)           | bldgclass(0)          | bldgclass(1)          | bldgclass(1)           | bldgclass(2)         | bldgclass(2)           | bldgclass(3)         | bldgclass(3)           | bldgclass(4)         | bldgclass(4)         | bldgclass(5)          | bldgclass(5)          |
# +--------------+------------------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+----------------------+------------------------+----------------------+----------------------+-----------------------+-----------------------+
# | violations   | violations(0)          | violations(1)         | violations(0)         | violations(1)          | violations(0)        | violations(1)          | violations(0)        | violations(1)          | violations(0)        | violations(1)        | violations(0)         | violations(1)         |
# +--------------+------------------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+----------------------+------------------------+----------------------+----------------------+-----------------------+-----------------------+
# | yearbuilt(0) | 0.00016320535313558285 | 0.0018656716417910447 | 0.0002179700758224478 | 0.00038895371450797355 | 0.000667573247620225 | 0.00018947767321417293 | 0.007118375955707883 | 0.00035790980672870435 | 0.020439448134900357 | 0.001201923076923077 | 0.0003905814083249637 | 0.0006309148264984228 |
# +--------------+------------------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+----------------------+------------------------+----------------------+----------------------+-----------------------+-----------------------+
# | yearbuilt(1) | 0.9998367946468644     | 0.9981343283582089    | 0.9997820299241775    | 0.999611046285492      | 0.9993324267523798   | 0.9998105223267858     | 0.9928816240442921   | 0.9996420901932713     | 0.9795605518650996   | 0.9987980769230769   | 0.9996094185916751    | 0.9993690851735015    |
# +--------------+------------------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+----------------------+------------------------+----------------------+----------------------+-----------------------+-----------------------+
# CPD of affordability_flag:
# +-----------------------+---+
# | affordability_flag(0) | 1 |
# +-----------------------+---+
# CPD of violations:
# +---------------+----------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+--------------------+-------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+
# | bldgclass     | bldgclass(0)         | bldgclass(0)         | bldgclass(0)        | bldgclass(0)         | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)         | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(2) | bldgclass(2) | bldgclass(2) | bldgclass(2) | bldgclass(2)        | bldgclass(2)        | bldgclass(2)       | bldgclass(2)      | bldgclass(2) | bldgclass(2) | bldgclass(2) | bldgclass(2) | bldgclass(2)       | bldgclass(2)      | bldgclass(2)       | bldgclass(2)        | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3)      | bldgclass(3)       | bldgclass(3)       | bldgclass(3)       | bldgclass(3)       | bldgclass(3)        | bldgclass(3)        | bldgclass(3)        | bldgclass(4) | bldgclass(4) | bldgclass(4) | bldgclass(4) | bldgclass(4)        | bldgclass(4)        | bldgclass(4) | bldgclass(4)        | bldgclass(4)        | bldgclass(4)        | bldgclass(4)        | bldgclass(4)       | bldgclass(4)       | bldgclass(4)        | bldgclass(4) | bldgclass(4)       | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        |
# +---------------+----------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+--------------------+-------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+
# | landuse       | landuse(0)           | landuse(0)           | landuse(0)          | landuse(0)           | landuse(1)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(3)   | landuse(3)   | landuse(3)   | landuse(3)   | landuse(0)          | landuse(0)          | landuse(0)          | landuse(0)           | landuse(1)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(3)   | landuse(3)   | landuse(3)   | landuse(3)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(1)          | landuse(1)          | landuse(1)         | landuse(1)        | landuse(2)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(3)         | landuse(3)        | landuse(3)         | landuse(3)          | landuse(0)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(2)        | landuse(2)         | landuse(2)         | landuse(2)         | landuse(3)         | landuse(3)          | landuse(3)          | landuse(3)          | landuse(0)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(1)          | landuse(1)          | landuse(1)   | landuse(1)          | landuse(2)          | landuse(2)          | landuse(2)          | landuse(2)         | landuse(3)         | landuse(3)          | landuse(3)   | landuse(3)         | landuse(0)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(3)          | landuse(3)          | landuse(3)          | landuse(3)          |
# +---------------+----------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+--------------------+-------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+
# | residfar      | residfar(0)          | residfar(1)          | residfar(2)         | residfar(3)          | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)         | residfar(1)         | residfar(2)         | residfar(3)          | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)         | residfar(1)         | residfar(2)        | residfar(3)       | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)        | residfar(1)       | residfar(2)        | residfar(3)         | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)       | residfar(1)        | residfar(2)        | residfar(3)        | residfar(0)        | residfar(1)         | residfar(2)         | residfar(3)         | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)         | residfar(1)         | residfar(2)  | residfar(3)         | residfar(0)         | residfar(1)         | residfar(2)         | residfar(3)        | residfar(0)        | residfar(1)         | residfar(2)  | residfar(3)        | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)         | residfar(1)         | residfar(2)         | residfar(3)         |
# +---------------+----------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+--------------------+-------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+
# | violations(0) | 0.9791870497198256   | 0.9724080267558528   | 0.9736842105263158  | 0.9824561403508771   | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.963630465342609   | 0.9503681483501499  | 0.9728813559322034  | 0.9545454545454546   | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.903805976927968   | 0.7746802129873309  | 0.6776496430532675 | 0.862475442043222 | 0.5          | 0.5          | 0.5          | 0.5          | 0.6849148418491484 | 0.563654518222666 | 0.6495557749259625 | 0.807372175980975   | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.632088520055325 | 0.5209692451071761 | 0.5862341772151899 | 0.8811881188118812 | 0.6163522012578616 | 0.47112211221122113 | 0.44854881266490765 | 0.6784140969162996  | 0.5          | 0.5          | 0.5          | 0.5          | 0.8663809894818855  | 0.7921686746987951  | 0.9          | 0.9047619047619048  | 0.8181818181818182  | 0.6673819742489271  | 0.8333333333333334  | 0.9152542372881356 | 0.3333333333333333 | 0.45454545454545453 | 0.25         | 0.6666666666666666 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.9375279392042914  | 0.9045285029302078  | 0.8824503311258278  | 0.8937282229965157  |
# +---------------+----------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+--------------------+-------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+
# | violations(1) | 0.020812950280174332 | 0.027591973244147156 | 0.02631578947368421 | 0.017543859649122806 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.03636953465739105 | 0.04963185164985001 | 0.02711864406779661 | 0.045454545454545456 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.09619402307203197 | 0.22531978701266908 | 0.3223503569467326 | 0.137524557956778 | 0.5          | 0.5          | 0.5          | 0.5          | 0.3150851581508516 | 0.436345481777334 | 0.3504442250740375 | 0.19262782401902498 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.367911479944675 | 0.4790307548928239 | 0.4137658227848101 | 0.1188118811881188 | 0.3836477987421384 | 0.5288778877887789  | 0.5514511873350924  | 0.32158590308370044 | 0.5          | 0.5          | 0.5          | 0.5          | 0.13361901051811453 | 0.20783132530120482 | 0.1          | 0.09523809523809523 | 0.18181818181818182 | 0.33261802575107297 | 0.16666666666666666 | 0.0847457627118644 | 0.6666666666666666 | 0.5454545454545454  | 0.75         | 0.3333333333333333 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.06247206079570854 | 0.09547149706979222 | 0.11754966887417219 | 0.10627177700348432 |
# +---------------+----------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+--------------------+-------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+
# CPD of landuse:
# +------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+------------------------+
# | bldgclass  | bldgclass(0)          | bldgclass(1)          | bldgclass(2)           | bldgclass(3)          | bldgclass(4)           | bldgclass(5)           |
# +------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+------------------------+
# | landuse(0) | 0.9998802156118985    | 0.9999550898203593    | 1.0338802559887513e-05 | 7.590708972218005e-05 | 0.00021070375052675939 | 5.1263648946532017e-05 |
# +------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+------------------------+
# | landuse(1) | 3.992812936713915e-05 | 1.497005988023952e-05 | 0.9309678153076311     | 7.590708972218005e-05 | 0.8362831858407079     | 5.1263648946532017e-05 |
# +------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+------------------------+
# | landuse(2) | 3.992812936713915e-05 | 1.497005988023952e-05 | 1.0338802559887513e-05 | 0.8330803097009261    | 0.16055625790139064    | 5.1263648946532017e-05 |
# +------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+------------------------+
# | landuse(3) | 3.992812936713915e-05 | 1.497005988023952e-05 | 0.06901150708724915    | 0.16676787611962957   | 0.0029498525073746312  | 0.9998462090531604     |
# +------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+------------------------+
# (violations _|_ affordability_flag | residfar, landuse, bldgclass)
# {'unitsres': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'violations', 'landuse'])}
# {'bldgclass': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'violations', 'landuse'])}
# {'subsidies_flag': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'violations', 'landuse'])}
# {'ownertype': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'violations', 'landuse'])}
# {'residfar': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'violations', 'landuse'])}
# {'yearbuilt': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'violations', 'landuse'])}
# {'affordability_flag': set(['affordability_flag'])}
# {'violations': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'violations', 'landuse'])}
# {'landuse': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'violations', 'landuse'])}

# %%
from collections import defaultdict
from pgmpy.inference import VariableElimination
def temp_predict(model,data):
    missing_variables = list(set(model.nodes()) - set(data.columns))
    pred_values = defaultdict(list)
    model_inference = VariableElimination(model)
    count = 0
    for index, data_point in data.iterrows():
        count = count+1
        if count %1000 == 1:
          print count
        states_dict = model_inference.map_query(variables=missing_variables, evidence=data_point.astype(int).to_dict())
        for k, v in states_dict.items():
            pred_values[k].append(v)
    return pd.DataFrame(pred_values, index=data.index)

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')
test_x = data18test.drop(columns=['violations'])
predicted_test = temp_predict(best_model, test_x)
print "Out of sample:",(data18test.loc[:,'violations']==predicted_test['violations']).mean()
# Out:
# Out of sample: 0.8827111323526808

# %%
train_x = data18train.drop(columns=['violations'])
predicted_train = temp_predict(best_model, train_x)
print "In of sample:",(data18train.loc[:,'violations']==predicted_train['violations']).mean()

# %%
data18smaller = pd.read_csv("data14smaller_2.csv", low_memory = False, dtype = {'subsidies_flag':"int64"})

# %%
# new indicator
data18train, data18test = train_test_split(data18smaller,random_state=9,test_size=0.2)
hc = HillClimbSearch(data18train, scoring_method=BicScore(data18train))
best_model = hc.estimate()
print(best_model.edges())
# Out:
# [('bldgclass', 'violations'), ('bldgclass', 'landuse'), ('bldgclass', 'ownertype'), ('bldgclass', 'subsidies_flag'), ('residfar', 'unit_ratio'), ('residfar', 'violations'), ('residfar', 'landuse'), ('residfar', 'yearbuilt'), ('residfar', 'bldgclass'), ('yearbuilt', 'violations'), ('yearbuilt', 'ownertype'), ('yearbuilt', 'subsidies_flag'), ('yearbuilt', 'bldgclass'), ('unit_ratio', 'yearbuilt'), ('unit_ratio', 'bldgclass'), ('violations', 'subsidies_flag'), ('violations', 'landuse')]

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')

for cpd in best_model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
    
print best_model.local_independencies('violations')

for thenode in best_model.nodes():
    print best_model.active_trail_nodes(thenode)
# Out:
# CPD of bldgclass:
# +--------------+-----------------------+----------------------+------------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+---------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+---------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | residfar     | residfar(0)           | residfar(0)          | residfar(0)            | residfar(0)          | residfar(0)          | residfar(0)           | residfar(0)           | residfar(0)           | residfar(0)          | residfar(0)           | residfar(0)          | residfar(0)           | residfar(0)   | residfar(0)           | residfar(0)           | residfar(0)           | residfar(0)           | residfar(0)           | residfar(0)           | residfar(0)           | residfar(0)           | residfar(0)           | residfar(0)          | residfar(0)           | residfar(0)          | residfar(1)           | residfar(1)           | residfar(1)          | residfar(1)          | residfar(1)           | residfar(1)           | residfar(1)           | residfar(1)           | residfar(1)           | residfar(1)   | residfar(1)           | residfar(1)           | residfar(1)           | residfar(1)           | residfar(1)          | residfar(1)           | residfar(1)          | residfar(1)         | residfar(1)           | residfar(1)           | residfar(1)           | residfar(1)          | residfar(1)           | residfar(1)           | residfar(1)           | residfar(2)          | residfar(2)           | residfar(2)           | residfar(2)          | residfar(2)           | residfar(2)          | residfar(2)           | residfar(2)          | residfar(2)           | residfar(2)           | residfar(2)           | residfar(2)          | residfar(2)          | residfar(2)           | residfar(2)          | residfar(2)           | residfar(2)           | residfar(2)           | residfar(2)   | residfar(2)          | residfar(2)           | residfar(2)         | residfar(2)          | residfar(2)          | residfar(2)          | residfar(3)           | residfar(3)            | residfar(3)           | residfar(3)          | residfar(3)           | residfar(3)          | residfar(3)           | residfar(3)          | residfar(3)           | residfar(3)          | residfar(3)          | residfar(3)          | residfar(3)          | residfar(3)          | residfar(3)          | residfar(3)         | residfar(3)         | residfar(3)          | residfar(3)          | residfar(3)         | residfar(3)          | residfar(3)          | residfar(3)          | residfar(3)          | residfar(3)          |
# +--------------+-----------------------+----------------------+------------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+---------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+---------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | unit_ratio   | unit_ratio(0)         | unit_ratio(0)        | unit_ratio(0)          | unit_ratio(0)        | unit_ratio(0)        | unit_ratio(1)         | unit_ratio(1)         | unit_ratio(1)         | unit_ratio(1)        | unit_ratio(1)         | unit_ratio(2)        | unit_ratio(2)         | unit_ratio(2) | unit_ratio(2)         | unit_ratio(2)         | unit_ratio(3)         | unit_ratio(3)         | unit_ratio(3)         | unit_ratio(3)         | unit_ratio(3)         | unit_ratio(4)         | unit_ratio(4)         | unit_ratio(4)        | unit_ratio(4)         | unit_ratio(4)        | unit_ratio(0)         | unit_ratio(0)         | unit_ratio(0)        | unit_ratio(0)        | unit_ratio(0)         | unit_ratio(1)         | unit_ratio(1)         | unit_ratio(1)         | unit_ratio(1)         | unit_ratio(1) | unit_ratio(2)         | unit_ratio(2)         | unit_ratio(2)         | unit_ratio(2)         | unit_ratio(2)        | unit_ratio(3)         | unit_ratio(3)        | unit_ratio(3)       | unit_ratio(3)         | unit_ratio(3)         | unit_ratio(4)         | unit_ratio(4)        | unit_ratio(4)         | unit_ratio(4)         | unit_ratio(4)         | unit_ratio(0)        | unit_ratio(0)         | unit_ratio(0)         | unit_ratio(0)        | unit_ratio(0)         | unit_ratio(1)        | unit_ratio(1)         | unit_ratio(1)        | unit_ratio(1)         | unit_ratio(1)         | unit_ratio(2)         | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)         | unit_ratio(2)        | unit_ratio(3)         | unit_ratio(3)         | unit_ratio(3)         | unit_ratio(3) | unit_ratio(3)        | unit_ratio(4)         | unit_ratio(4)       | unit_ratio(4)        | unit_ratio(4)        | unit_ratio(4)        | unit_ratio(0)         | unit_ratio(0)          | unit_ratio(0)         | unit_ratio(0)        | unit_ratio(0)         | unit_ratio(1)        | unit_ratio(1)         | unit_ratio(1)        | unit_ratio(1)         | unit_ratio(1)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(3)       | unit_ratio(3)       | unit_ratio(3)        | unit_ratio(3)        | unit_ratio(3)       | unit_ratio(4)        | unit_ratio(4)        | unit_ratio(4)        | unit_ratio(4)        | unit_ratio(4)        |
# +--------------+-----------------------+----------------------+------------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+---------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+---------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | yearbuilt    | yearbuilt(0)          | yearbuilt(1)         | yearbuilt(2)           | yearbuilt(3)         | yearbuilt(4)         | yearbuilt(0)          | yearbuilt(1)          | yearbuilt(2)          | yearbuilt(3)         | yearbuilt(4)          | yearbuilt(0)         | yearbuilt(1)          | yearbuilt(2)  | yearbuilt(3)          | yearbuilt(4)          | yearbuilt(0)          | yearbuilt(1)          | yearbuilt(2)          | yearbuilt(3)          | yearbuilt(4)          | yearbuilt(0)          | yearbuilt(1)          | yearbuilt(2)         | yearbuilt(3)          | yearbuilt(4)         | yearbuilt(0)          | yearbuilt(1)          | yearbuilt(2)         | yearbuilt(3)         | yearbuilt(4)          | yearbuilt(0)          | yearbuilt(1)          | yearbuilt(2)          | yearbuilt(3)          | yearbuilt(4)  | yearbuilt(0)          | yearbuilt(1)          | yearbuilt(2)          | yearbuilt(3)          | yearbuilt(4)         | yearbuilt(0)          | yearbuilt(1)         | yearbuilt(2)        | yearbuilt(3)          | yearbuilt(4)          | yearbuilt(0)          | yearbuilt(1)         | yearbuilt(2)          | yearbuilt(3)          | yearbuilt(4)          | yearbuilt(0)         | yearbuilt(1)          | yearbuilt(2)          | yearbuilt(3)         | yearbuilt(4)          | yearbuilt(0)         | yearbuilt(1)          | yearbuilt(2)         | yearbuilt(3)          | yearbuilt(4)          | yearbuilt(0)          | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)          | yearbuilt(4)         | yearbuilt(0)          | yearbuilt(1)          | yearbuilt(2)          | yearbuilt(3)  | yearbuilt(4)         | yearbuilt(0)          | yearbuilt(1)        | yearbuilt(2)         | yearbuilt(3)         | yearbuilt(4)         | yearbuilt(0)          | yearbuilt(1)           | yearbuilt(2)          | yearbuilt(3)         | yearbuilt(4)          | yearbuilt(0)         | yearbuilt(1)          | yearbuilt(2)         | yearbuilt(3)          | yearbuilt(4)         | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)         | yearbuilt(4)         | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)         | yearbuilt(3)         | yearbuilt(4)        | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)         | yearbuilt(4)         |
# +--------------+-----------------------+----------------------+------------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+---------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+---------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | bldgclass(0) | 0.08476357267950964   | 0.10095389507154214  | 0.08637236084452975    | 0.055441478439425054 | 0.03984575835475578  | 0.16611842105263158   | 0.2069364161849711    | 0.17734282325029657   | 0.19602272727272727  | 0.07160342717258263   | 0.3024258760107817   | 0.4134742404227213    | 0.36875       | 0.3696303696303696    | 0.1213903743315508    | 0.5020995800839833    | 0.696969696969697     | 0.6452459016393443    | 0.4
845278725825  | 0.015517241379310345 | 0.027754415475189236 | 0.11166916704715935   | 0.13399879007864487    | 0.2518027961736571    | 0.04420350291909925  | 0.07841823056300268   | 0.1349408764201252   | 0.11244315832988838   | 0.2212784979883773   | 0.02853673345476624   | 0.023606023606023607 | 0.13328934345100626  | 0.21939586645468998  | 0.3591626882115314   | 0.04076433121019108  | 0.030756087142246903 | 0.11540900443880786 | 0.13741496598639455 | 0.25426136363636365  | 0.048723897911832945 | 0.02077562326869806 | 0.08587314662273476  | 0.10516605166051661  | 0.22800925925925927  | 0.08097165991902834  | 0.047238372093023256 |
# +--------------+-----------------------+----------------------+------------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+---------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+---------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# CPD of subsidies_flag:
# +-------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+----------------------+----------------------+---------------+----------------------+----------------------+----------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+---------------+----------------------+-----------------------+----------------------+------------------------+------------------------+----------------------+------------------------+-----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+---------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+---------------------+---------------------+---------------+---------------------+---------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+----------------------+----------------------+---------------------+---------------+---------------------+
# | bldgclass         | bldgclass(0)           | bldgclass(0)          | bldgclass(0)          | bldgclass(0)           | bldgclass(0)           | bldgclass(0)         | bldgclass(0)         | bldgclass(0)  | bldgclass(0)         | bldgclass(0)         | bldgclass(1)         | bldgclass(1)           | bldgclass(1)          | bldgclass(1)          | bldgclass(1)           | bldgclass(1)          | bldgclass(1)  | bldgclass(1)         | bldgclass(1)          | bldgclass(1)         | bldgclass(2)           | bldgclass(2)           | bldgclass(2)         | bldgclass(2)           | bldgclass(2)          | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(3)          | bldgclass(3)          | bldgclass(3)          | bldgclass(3)          | bldgclass(3)          | bldgclass(3)        | bldgclass(3)       | bldgclass(3)        | bldgclass(3)        | bldgclass(3)        | bldgclass(4)          | bldgclass(4)         | bldgclass(4)          | bldgclass(4)         | bldgclass(4)          | bldgclass(4)        | bldgclass(4)        | bldgclass(4)  | bldgclass(4)        | bldgclass(4)        | bldgclass(5)           | bldgclass(5)         | bldgclass(5)           | bldgclass(5)          | bldgclass(5)          | bldgclass(5)         | bldgclass(5)         | bldgclass(5)        | bldgclass(5)  | bldgclass(5)        |
# ...
# | residfar   | residfar(0)           | residfar(0)           | residfar(1)            | residfar(1)          | residfar(2)            | residfar(2)          | residfar(3)           | residfar(3)        | residfar(0)           | residfar(0)          | residfar(1)           | residfar(1)           | residfar(2)           | residfar(2)          | residfar(3)           | residfar(3)           | residfar(0)            | residfar(0)           | residfar(1)           | residfar(1)           | residfar(2)           | residfar(2)           | residfar(3)           | residfar(3)           | residfar(0)           | residfar(0)         | residfar(1)          | residfar(1)           | residfar(2)           | residfar(2)           | residfar(3)            | residfar(3)            | residfar(0)           | residfar(0)          | residfar(1)           | residfar(1)          | residfar(2)          | residfar(2)          | residfar(3)           | residfar(3)           | residfar(0)           | residfar(0)          | residfar(1)           | residfar(1)          | residfar(2)            | residfar(2)          | residfar(3)            | residfar(3)           |
# +------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+----------------------+-----------------------+--------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------------+----------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+------------------------+----------------------+------------------------+-----------------------+

# +------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+----------------------+-----------------------+--------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------------+----------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+------------------------+----------------------+------------------------+-----------------------+
# | landuse(2) | 7.427213309566251e-05 | 0.0036363636363636364 | 0.00018487705675725643 | 0.008695652173913044 | 0.00030883261272390367 | 0.012195121951219513 | 0.0004038772213247173 | 0.0136986301369863 | 5.900401227283455e-05 | 0.001447178002894356 | 6.210408644888833e-05 | 0.0016835016835016834 | 4.890453834115806e-05 | 0.001303780964797914 | 9.317059536010435e-05 | 0.0017543859649122807 | 0.00019425019425019425 | 0.0010845986984815619 | 9.575792396820837e-05 | 0.0010976948408342481 | 2.890089881795324e-05 | 0.0002677376171352075 | 3.268614761064261e-05 | 9.645992090286486e-05 | 0.9400630914826499    | 0.8061224489795918  | 0.9764309764309764   | 0.9419354838709677    | 0.9097222222222222    | 0.9318181818181818    | 0.828198859005705      | 0.7875026749411513     | 0.05319148936170213   | 0.10476190476190476  | 0.031078610603290677  | 0.031578947368421054 | 0.07277452891487979  | 0.08241758241758242  | 0.28664072632944226   | 0.367170626349892     | 0.0005730659025787965 | 0.007518796992481203 | 0.0011173184357541898 | 0.015151515151515152 | 0.00017277125086385625 | 0.002688172043010753 | 0.00010464629552113855 | 0.0010131712259371835 |
# +------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+----------------------+-----------------------+--------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------------+----------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+------------------------+----------------------+------------------------+-----------------------+
# | landuse(3) | 7.427213309566251e-05 | 0.0036363636363636364 | 0.00018487705675725643 | 0.008695652173913044 | 0.00030883261272390367 | 0.012195121951219513 | 0.0004038772213247173 | 0.0136986301369863 | 5.900401227283455e-05 | 0.001447178002894356 | 6.210408644888833e-05 | 0.0016835016835016834 | 4.890453834115806e-05 | 0.001303780964797914 | 9.317059536010435e-05 | 0.0017543859649122807 | 0.02156177156177156    | 0.07158351409978309   | 0.003638801110791918  | 0.013172338090010977  | 0.011531458628363342  | 0.05060240963855422   | 0.11887951885990718   | 0.21857818076589178   | 0.05362776025236593   | 0.17346938775510204 | 0.016835016835016835 | 0.04516129032258064   | 0.08796296296296297   | 0.06493506493506493   | 0.17147514262428687    | 0.21206933447464155    | 0.0035460992907801418 | 0.009523809523809525 | 0.0018281535648994515 | 0.010526315789473684 | 0.000649772579597141 | 0.01098901098901099  | 0.0038910505836575876 | 0.008639308855291577  | 0.9982808022922636    | 0.9774436090225563   | 0.9966480446927374    | 0.9545454545454546   | 0.9994816862474084     | 0.9919354838709677   | 0.9996860611134366     | 0.9969604863221885    |
# +------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+----------------------+-----------------------+--------------------+-----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------------+----------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+------------------------+----------------------+------------------------+-----------------------+
# (violations _|_ unit_ratio, ownertype | residfar, yearbuilt, bldgclass)
# {'bldgclass': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'subsidies_flag': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'ownertype': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'residfar': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'yearbuilt': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'unit_ratio': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'violations': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'landuse': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')
test_x = data18test.drop(columns=['violations'])
predicted_test = temp_predict(best_model, test_x)
print "Out of sample:",(data18test.loc[:,'violations']==predicted_test['violations']).mean()
# Out:
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 34001
# 35001
# 36001
# 37001
# 38001
# 39001
# 40001
# 41001
# 42001
# 43001
# 44001
# 45001
# 46001
# 47001
# 48001
# 49001
# 50001
# 51001
# 52001
# 53001
# 54001
# 55001
# 56001
# Out of sample: 0.8961818278370771
