# %%
import numpy as np
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e53cefaa-0921-4354-b625-321ea88fda03" name="files[]" multiple disabled />
#      <output id="result-e53cefaa-0921-4354-b625-321ea88fda03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data16smaller_2.csv to data16smaller_2.csv

# %%
data18smaller = pd.read_csv("data16smaller_0.csv", low_memory = False, dtype = {'subsidies_flag':"int64"})
#data_all_smaller = data_all_smaller.iloc[:,1:]

# %%
# !pip install pgmpy==0.1.7
from pgmpy.estimators import HillClimbSearch, BicScore, BayesianEstimator
from pgmpy.models import BayesianModel
from sklearn.model_selection import train_test_split
from pgmpy.inference import VariableElimination
# Out:
# Collecting pgmpy==0.1.7
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python2.7/dist-packages (from pgmpy==0.1.7) (1.2.1)
# Requirement already satisfied: networkx<1.12,>=1.11 in /usr/local/lib/python2.7/dist-packages (from pgmpy==0.1.7) (1.11)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python2.7/dist-packages (from pgmpy==0.1.7) (1.16.3)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python2.7/dist-packages (from networkx<1.12,>=1.11->pgmpy==0.1.7) (4.4.0)
# Installing collected packages: pgmpy
# Successfully installed pgmpy-0.1.7

# %%
data18train, data18test = train_test_split(data18smaller,random_state=9,test_size=0.2)
hc = HillClimbSearch(data18train, scoring_method=BicScore(data18train))
best_model = hc.estimate()
print(best_model.edges())
# Out:
# [('bldgclass', 'residfar'), ('bldgclass', 'yearbuilt'), ('bldgclass', 'violations'), ('bldgclass', 'ownertype'), ('bldgclass', 'subsidies_flag'), ('subsidies_flag', 'affordability_flag'), ('residfar', 'violations'), ('residfar', 'subsidies_flag'), ('violations', 'yearbuilt'), ('violations', 'subsidies_flag'), ('violations', 'ownertype'), ('violations', 'unitsres'), ('violations', 'affordability_flag'), ('landuse', 'residfar'), ('landuse', 'violations'), ('landuse', 'unitsres'), ('landuse', 'bldgclass')]

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')

for cpd in best_model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
    
print best_model.local_independencies('violations')

for thenode in best_model.nodes():
    print best_model.active_trail_nodes(thenode)
# Out:
# WARNING:root:Replacing existing CPD for unitsres
# WARNING:root:Replacing existing CPD for bldgclass
# WARNING:root:Replacing existing CPD for subsidies_flag
# WARNING:root:Replacing existing CPD for ownertype
# WARNING:root:Replacing existing CPD for residfar
# WARNING:root:Replacing existing CPD for yearbuilt
# WARNING:root:Replacing existing CPD for affordability_flag
# WARNING:root:Replacing existing CPD for violations
# WARNING:root:Replacing existing CPD for landuse
# CPD of unitsres:
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+---------------+---------------+
# | landuse     | landuse(0)             | landuse(0)           | landuse(1)             | landuse(1)            | landuse(2)             | landuse(2)           | landuse(3)             | landuse(3)            | landuse(4)    | landuse(4)    |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+---------------+---------------+
# | violations  | violations(0)          | violations(1)        | violations(0)          | violations(1)         | violations(0)          | violations(1)        | violations(0)          | violations(1)         | violations(0) | violations(1) |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+---------------+---------------+
# | unitsres(0) | 0.9999549244985351     | 0.9987134126728852   | 0.9999501849384161     | 0.9997093445720099    | 0.9966036621382162     | 0.959968907889623    | 0.999827653065621      | 0.9950834064969272    | 0.5           | 0.2           |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+---------------+---------------+
# | unitsres(1) | 1.1268875366238449e-05 | 0.000321646831778707 | 1.2453765395967471e-05 | 7.266385699752942e-05 | 0.00014766686355581807 | 0.02487368830159347  | 4.3086733594726185e-05 | 0.0001755926251097454 | 0.125         | 0.2           |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+---------------+---------------+
# | unitsres(2) | 1.1268875366238449e-05 | 0.000321646831778707 | 1.2453765395967471e-05 | 7.266385699752942e-05 | 0.0010336680448907265  | 0.003692188107267781 | 4.3086733594726185e-05 | 0.0001755926251097454 | 0.125         | 0.2           |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+---------------+---------------+
# | unitsres(3) | 1.1268875366238449e-05 | 0.000321646831778707 | 1.2453765395967471e-05 | 7.266385699752942e-05 | 0.002067336089781453   | 0.000194325689856199 | 4.3086733594726185e-05 | 0.004389815627743635  | 0.125         | 0.2           |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+---------------+---------------+
# | unitsres(4) | 1.1268875366238449e-05 | 0.000321646831778707 | 1.2453765395967471e-05 | 7.266385699752942e-05 | 0.00014766686355581807 | 0.011270890011659542 | 4.3086733594726185e-05 | 0.0001755926251097454 | 0.125         | 0.2           |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+---------------+---------------+
# CPD of bldgclass:
# +--------------+------------------------+------------------------+-----------------------+-----------------------+--------------------+
# | landuse      | landuse(0)             | landuse(1)             | landuse(2)            | landuse(3)            | landuse(4)         |
# +--------------+------------------------+------------------------+-----------------------+-----------------------+--------------------+
# | bldgclass(0) | 0.2711633730742011     | 1.0632076976237309e-05 | 8.393486654356219e-05 | 3.460207612456748e-05 | 0.1111111111111111 |
# +--------------+------------------------+------------------------+-----------------------+-----------------------+--------------------+
# | bldgclass(1) | 0.7287930752898906     | 1.0632076976237309e-05 | 8.393486654356219e-05 | 3.460207612456748e-05 | 0.1111111111111111 |
# +--------------+------------------------+------------------------+-----------------------+-----------------------+--------------------+
# | bldgclass(2) | 1.0887908977080951e-05 | 0.9551645313912073     | 8.393486654356219e-05 | 0.23121107266435986   | 0.1111111111111111 |
# +--------------+------------------------+------------------------+-----------------------+-----------------------+--------------------+
# | bldgclass(3) | 1.0887908977080951e-05 | 1.0632076976237309e-05 | 0.9268087963740138    | 0.09217993079584776   | 0.1111111111111111 |
# +--------------+------------------------+------------------------+-----------------------+-----------------------+--------------------+
# | bldgclass(4) | 1.0887908977080951e-05 | 0.044792940300887776   | 0.07285546415981199   | 0.0004152249134948097 | 0.4444444444444444 |
# +--------------+------------------------+------------------------+-----------------------+-----------------------+--------------------+
# | bldgclass(5) | 1.0887908977080951e-05 | 1.0632076976237309e-05 | 8.393486654356219e-05 | 0.6761245674740485    | 0.1111111111111111 |
# +--------------+------------------------+------------------------+-----------------------+-----------------------+--------------------+
# CPD of subsidies_flag:
# +-------------------+-----------------------+----------------------+------------------------+----------------------+----------------------+---------------------+---------------+---------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+---------------------+----------------------+---------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+-----------------------+----------------------+----------------------+---------------------+----------------------+--------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+---------------------+----------------------+---------------+----------------------+----------------------+-----------------------+----------------------+----------------------+---------------------+-----------------------+----------------------+
# | bldgclass         | bldgclass(0)          | bldgclass(0)         | bldgclass(0)           | bldgclass(0)         | bldgclass(0)         | bldgclass(0)        | bldgclass(0)  | bldgclass(0)  | bldgclass(1)           | bldgclass(1)           | bldgclass(1)          | bldgclass(1)          | bldgclass(1)          | bldgclass(1)        | bldgclass(1)         | bldgclass(1)  | bldgclass(2)         | bldgclass(2)        | bldgclass(2)         | bldgclass(2)        | bldgclass(2)         | bldgclass(2)        | bldgclass(2)          | bldgclass(2)         | bldgclass(3)         | bldgclass(3)        | bldgclass(3)         | bldgclass(3)       | bldgclass(3)        | bldgclass(3)        | bldgclass(3)         | bldgclass(3)        | bldgclass(4)        | bldgclass(4)        | bldgclass(4)       | bldgclass(4)        | bldgclass(4)       | bldgclass(4)        | bldgclass(4)         | bldgclass(4)  | bldgclass(5)         | bldgclass(5)         | bldgclass(5)          | bldgclass(5)         | bldgclass(5)         | bldgclass(5)        | bldgclass(5)          | bldgclass(5)         |
# +-------------------+-----------------------+----------------------+------------------------+----------------------+----------------------+---------------------+---------------+---------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+---------------------+----------------------+---------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+-----------------------+----------------------+----------------------+---------------------+----------------------+--------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+---------------------+----------------------+---------------+----------------------+----------------------+-----------------------+----------------------+----------------------+---------------------+-----------------------+----------------------+
# | residfar          | residfar(0)           | residfar(0)          | residfar(1)            | residfar(1)          | residfar(2)          | residfar(2)         | residfar(3)   | residfar(3)   | residfar(0)            | residfar(0)            | residfar(1)           | residfar(1)           | residfar(2)           | residfar(2)         | residfar(3)          | residfar(3)   | residfar(0)          | residfar(0)         | residfar(1)          | residfar(1)         | residfar(2)          | residfar(2)         | residfar(3)           | residfar(3)          | residfar(0)          | residfar(0)         | residfar(1)          | residfar(1)        | residfar(2)         | residfar(2)         | residfar(3)          | residfar(3)         | residfar(0)         | residfar(0)         | residfar(1)        | residfar(1)         | residfar(2)        | residfar(2)         | residfar(3)          | residfar(3)   | residfar(0)          | residfar(0)          | residfar(1)           | residfar(1)          | residfar(2)          | residfar(2)         | residfar(3)           | residfar(3)          |
# +-------------------+-----------------------+----------------------+------------------------+----------------------+----------------------+---------------------+---------------+---------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+---------------------+----------------------+---------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+-----------------------+----------------------+----------------------+---------------------+----------------------+--------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+---------------------+----------------------+---------------+----------------------+----------------------+-----------------------+----------------------+----------------------+---------------------+-----------------------+----------------------+
# | violations        | violations(0)         | violations(1)        | violations(0)          | violations(1)        | violations(0)        | violations(1)       | violations(0) | violations(1) | violations(0)          | violations(1)          | violations(0)         | violations(1)         | violations(0)         | violations(1)       | violations(0)        | violations(1) | violations(0)        | violations(1)       | violations(0)        | violations(1)       | violations(0)        | violations(1)       | violations(0)         | violations(1)        | violations(0)        | violations(1)       | violations(0)        | violations(1)      | violations(0)       | violations(1)       | violations(0)        | violations(1)       | violations(0)       | violations(1)       | violations(0)      | violations(1)       | violations(0)      | violations(1)       | violations(0)        | violations(1) | violations(0)        | violations(1)        | violations(0)         | violations(1)        | violations(0)        | violations(1)       | violations(0)         | violations(1)        |
# +-------------------+-----------------------+----------------------+------------------------+----------------------+----------------------+---------------------+---------------+---------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+---------------------+----------------------+---------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+-----------------------+----------------------+----------------------+---------------------+----------------------+--------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+---------------------+----------------------+---------------+----------------------+----------------------+-----------------------+----------------------+----------------------+---------------------+-----------------------+----------------------+

# +-------------+-----------------------+--------------+--------------+--------------+--------------+-----------------------+--------------+--------------+--------------+--------------+--------------+----------------------+--------------+---------------------+--------------+--------------+--------------+---------------------+---------------------+--------------+--------------+----------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+----------------------+--------------+
# | residfar(2) | 0.004416251806648466  | 0.25         | 0.25         | 0.25         | 0.25         | 0.004302424595527271  | 0.25         | 0.25         | 0.25         | 0.25         | 0.25         | 0.020146703620841266 | 0.25         | 0.14480179506357516 | 0.25         | 0.25         | 0.25         | 0.1129923042100498  | 0.161604799400075   | 0.25         | 0.25         | 0.015417457305502846 | 0.11940298507462686 | 0.2                 | 0.14285714285714285 | 0.25         | 0.25         | 0.25         | 0.032952975489945247 | 0.25         |
# +-------------+-----------------------+--------------+--------------+--------------+--------------+-----------------------+--------------+--------------+--------------+--------------+--------------+----------------------+--------------+---------------------+--------------+--------------+--------------+---------------------+---------------------+--------------+--------------+----------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+----------------------+--------------+
# | residfar(3) | 0.0025293078528986672 | 0.25         | 0.25         | 0.25         | 0.25         | 0.0003137184600905302 | 0.25         | 0.25         | 0.25         | 0.25         | 0.25         | 0.005365033781903585 | 0.25         | 0.12744951383694839 | 0.25         | 0.25         | 0.25         | 0.09406971480307831 | 0.21334833145856769 | 0.25         | 0.25         | 0.004981024667931689 | 0.06888633754305395 | 0.13333333333333333 | 0.2857142857142857  | 0.25         | 0.25         | 0.25         | 0.027068515581026454 | 0.25         |
# +-------------+-----------------------+--------------+--------------+--------------+--------------+-----------------------+--------------+--------------+--------------+--------------+--------------+----------------------+--------------+---------------------+--------------+--------------+--------------+---------------------+---------------------+--------------+--------------+----------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+----------------------+--------------+
# CPD of yearbuilt:
# +--------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+
# | bldgclass    | bldgclass(0)           | bldgclass(0)          | bldgclass(1)          | bldgclass(1)           | bldgclass(2)          | bldgclass(2)           | bldgclass(3)         | bldgclass(3)          | bldgclass(4)         | bldgclass(4)         | bldgclass(5)          | bldgclass(5)          |
# +--------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+
# | violations   | violations(0)          | violations(1)         | violations(0)         | violations(1)          | violations(0)         | violations(1)          | violations(0)        | violations(1)         | violations(0)        | violations(1)        | violations(0)         | violations(1)         |
# +--------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+
# | yearbuilt(0) | 0.00032848813336618213 | 0.0018050541516245488 | 0.0005436048769123243 | 0.00039154267815191856 | 0.0016758112167630775 | 0.00043848659483838637 | 0.009790949986768986 | 0.0008130081300813008 | 0.025665175417942075 | 0.009411764705882352 | 0.0008374741778795154 | 0.0006127450980392157 |
# +--------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+
# | yearbuilt(1) | 0.9996715118666338     | 0.9981949458483754    | 0.9994563951230877    | 0.9996084573218481     | 0.9983241887832369    | 0.9995615134051616     | 0.990209050013231    | 0.9991869918699187    | 0.9743348245820579   | 0.9905882352941177   | 0.9991625258221205    | 0.9993872549019608    |
# +--------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+
# CPD of affordability_flag:
# +-----------------------+------------------------+-----------------------+----------------------+----------------------+
# | subsidies_flag        | subsidies_flag(0)      | subsidies_flag(0)     | subsidies_flag(1)    | subsidies_flag(1)    |
# +-----------------------+------------------------+-----------------------+----------------------+----------------------+
# | violations            | violations(0)          | violations(1)         | violations(0)        | violations(1)        |
# +-----------------------+------------------------+-----------------------+----------------------+----------------------+
# | affordability_flag(0) | 0.9999596149283417     | 0.9985819152485819    | 0.9639737991266376   | 0.8619763694951665   |
# +-----------------------+------------------------+-----------------------+----------------------+----------------------+
# | affordability_flag(1) | 5.048133957282691e-06  | 4.170837504170838e-05 | 0.001091703056768559 | 0.004027926960257788 |
# +-----------------------+------------------------+-----------------------+----------------------+----------------------+
# | affordability_flag(2) | 5.048133957282691e-06  | 4.170837504170838e-05 | 0.002183406113537118 | 0.004027926960257788 |
# +-----------------------+------------------------+-----------------------+----------------------+----------------------+
# | affordability_flag(3) | 3.0288803743696143e-05 | 0.001334668001334668  | 0.03275109170305677  | 0.12996777658431793  |
# +-----------------------+------------------------+-----------------------+----------------------+----------------------+
# CPD of violations:
# +---------------+----------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+--------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+-------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+
# | bldgclass     | bldgclass(0)         | bldgclass(0)        | bldgclass(0)        | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(0) | bldgclass(1)        | bldgclass(1)         | bldgclass(1)        | bldgclass(1)         | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(1) | bldgclass(2) | bldgclass(2) | bldgclass(2) | bldgclass(2) | bldgclass(2)       | bldgclass(2)       | bldgclass(2)        | bldgclass(2)        | bldgclass(2) | bldgclass(2) | bldgclass(2) | bldgclass(2) | bldgclass(2)        | bldgclass(2)        | bldgclass(2)      | bldgclass(2)        | bldgclass(2) | bldgclass(2) | bldgclass(2) | bldgclass(2) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3)       | bldgclass(3)        | bldgclass(3)        | bldgclass(3)        | bldgclass(3)       | bldgclass(3)        | bldgclass(3)       | bldgclass(3)       | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(3) | bldgclass(4) | bldgclass(4) | bldgclass(4) | bldgclass(4) | bldgclass(4)       | bldgclass(4)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)        | bldgclass(4)        | bldgclass(4)       | bldgclass(4)        | bldgclass(4) | bldgclass(4) | bldgclass(4) | bldgclass(4)       | bldgclass(4) | bldgclass(4) | bldgclass(4) | bldgclass(4)       | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5) | bldgclass(5) | bldgclass(5) | bldgclass(5) |
# +---------------+----------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+--------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+-------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+
# | landuse       | landuse(0)           | landuse(0)          | landuse(0)          | landuse(0)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(3)   | landuse(3)   | landuse(3)   | landuse(3)   | landuse(4)   | landuse(4)   | landuse(4)   | landuse(4)   | landuse(0)          | landuse(0)           | landuse(0)          | landuse(0)           | landuse(1)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(3)   | landuse(3)   | landuse(3)   | landuse(3)   | landuse(4)   | landuse(4)   | landuse(4)   | landuse(4)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(1)         | landuse(1)         | landuse(1)          | landuse(1)          | landuse(2)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(3)          | landuse(3)          | landuse(3)        | landuse(3)          | landuse(4)   | landuse(4)   | landuse(4)   | landuse(4)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(2)         | landuse(2)          | landuse(2)          | landuse(2)          | landuse(3)         | landuse(3)          | landuse(3)         | landuse(3)         | landuse(4)   | landuse(4)   | landuse(4)   | landuse(4)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(1)         | landuse(1)          | landuse(1)           | landuse(1)          | landuse(2)          | landuse(2)          | landuse(2)         | landuse(2)          | landuse(3)   | landuse(3)   | landuse(3)   | landuse(3)         | landuse(4)   | landuse(4)   | landuse(4)   | landuse(4)         | landuse(0)   | landuse(0)   | landuse(0)   | landuse(0)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(1)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(2)   | landuse(3)          | landuse(3)          | landuse(3)          | landuse(3)          | landuse(4)   | landuse(4)   | landuse(4)   | landuse(4)   |
# +---------------+----------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+--------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+-------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+
# | residfar      | residfar(0)          | residfar(1)         | residfar(2)         | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)         | residfar(1)          | residfar(2)         | residfar(3)          | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)        | residfar(1)        | residfar(2)         | residfar(3)         | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)         | residfar(1)         | residfar(2)       | residfar(3)         | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)        | residfar(1)         | residfar(2)         | residfar(3)         | residfar(0)        | residfar(1)         | residfar(2)        | residfar(3)        | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)        | residfar(1)         | residfar(2)          | residfar(3)         | residfar(0)         | residfar(1)         | residfar(2)        | residfar(3)         | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)        | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)        | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  | residfar(0)         | residfar(1)         | residfar(2)         | residfar(3)         | residfar(0)  | residfar(1)  | residfar(2)  | residfar(3)  |
# +---------------+----------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+--------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+-------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+
# | violations(0) | 0.977994453886752    | 0.9760403530895334  | 0.9459459459459459  | 0.984375     | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.9630595471467367  | 0.9558436848309003   | 0.9515570934256056  | 0.9545454545454546   | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.9077454997804771 | 0.7762033630309849 | 0.6366648260629486  | 0.8281573498964804  | 0.5          | 0.5          | 0.5          | 0.5          | 0.6643192488262911  | 0.5255292652552926  | 0.608875128998968 | 0.6998827667057445  | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5628187297171998 | 0.503558988338634   | 0.5516413130504404  | 0.8682692307692308  | 0.6683937823834197 | 0.49390243902439024 | 0.4513888888888889 | 0.6666666666666666 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.8621933621933622 | 0.8272058823529411  | 0.9696969696969697   | 0.9090909090909091  | 0.8532608695652174  | 0.6876190476190476  | 0.6761904761904762 | 0.9016393442622951  | 0.5          | 0.7          | 0.25         | 0.6666666666666666 | 0.75         | 0.5          | 0.5          | 0.6666666666666666 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.9301433246811872  | 0.9080012616969825  | 0.8635658914728682  | 0.9018867924528302  | 0.5          | 0.5          | 0.5          | 0.5          |
# +---------------+----------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+--------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+-------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+
# | violations(1) | 0.022005546113248054 | 0.02395964691046658 | 0.05405405405405406 | 0.015625     | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.03694045285326331 | 0.044156315169099646 | 0.04844290657439446 | 0.045454545454545456 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.0922545002195229 | 0.2237966369690151 | 0.36333517393705134 | 0.17184265010351968 | 0.5          | 0.5          | 0.5          | 0.5          | 0.33568075117370894 | 0.47447073474470736 | 0.391124871001032 | 0.30011723329425555 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.4371812702828002 | 0.49644101166136606 | 0.44835868694955966 | 0.13173076923076923 | 0.3316062176165803 | 0.5060975609756098  | 0.5486111111111112 | 0.3333333333333333 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.1378066378066378 | 0.17279411764705882 | 0.030303030303030304 | 0.09090909090909091 | 0.14673913043478262 | 0.31238095238095237 | 0.3238095238095238 | 0.09836065573770492 | 0.5          | 0.3          | 0.75         | 0.3333333333333333 | 0.25         | 0.5          | 0.5          | 0.3333333333333333 | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.5          | 0.06985667531881277 | 0.09199873830301755 | 0.13643410852713178 | 0.09811320754716982 | 0.5          | 0.5          | 0.5          | 0.5          |
# +---------------+----------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+----------------------+---------------------+----------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+--------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+---------------------+---------------------+-------------------+---------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+---------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+
# CPD of landuse:
# +------------+-------------+
# | landuse(0) | 0.40512     |
# +------------+-------------+
# | landuse(1) | 0.414869    |
# +------------+-------------+
# | landuse(2) | 0.0525324   |
# +------------+-------------+
# | landuse(3) | 0.12746     |
# +------------+-------------+
# | landuse(4) | 1.76446e-05 |
# +------------+-------------+
#
# {'unitsres': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'bldgclass': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'subsidies_flag': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'ownertype': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'residfar': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'yearbuilt': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'affordability_flag': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'violations': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'landuse': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}

# %%
from collections import defaultdict
from pgmpy.inference import VariableElimination
def temp_predict(model,data):
    missing_variables = list(set(model.nodes()) - set(data.columns))
    pred_values = defaultdict(list)
    model_inference = VariableElimination(model)
    count = 0
    for index, data_point in data.iterrows():
        count = count+1
        if count %1000 == 1:
          print count
        states_dict = model_inference.map_query(variables=missing_variables, evidence=data_point.astype(int).to_dict())
        for k, v in states_dict.items():
            pred_values[k].append(v)
    return pd.DataFrame(pred_values, index=data.index)

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')
test_x = data18test.drop(columns=['violations'])
predicted_test = temp_predict(best_model, test_x)
print "Out of sample:",(data18test.loc[:,'violations']==predicted_test['violations']).mean()
# Out:
# WARNING:root:Replacing existing CPD for unitsres
# WARNING:root:Replacing existing CPD for bldgclass
# WARNING:root:Replacing existing CPD for subsidies_flag
# WARNING:root:Replacing existing CPD for ownertype
# WARNING:root:Replacing existing CPD for residfar
# WARNING:root:Replacing existing CPD for yearbuilt
# WARNING:root:Replacing existing CPD for affordability_flag
# WARNING:root:Replacing existing CPD for violations
# WARNING:root:Replacing existing CPD for landuse
# Out of sample: 0.8923139358435968

# %%
train_x = data18train.drop(columns=['violations'])
predicted_train = temp_predict(best_model, train_x)
print "In of sample:",(data18train.loc[:,'violations']==predicted_train['violations']).mean()

# %%
data18smaller = pd.read_csv("data16smaller_2.csv", low_memory = False, dtype = {'subsidies_flag':"int64"})

# %%
data18train, data18test = train_test_split(data18smaller,random_state=9,test_size=0.2)
hc = HillClimbSearch(data18train, scoring_method=BicScore(data18train))
best_model = hc.estimate()
print(best_model.edges())
# Out:
# [('bldgclass', 'residfar'), ('bldgclass', 'violations'), ('bldgclass', 'landuse'), ('bldgclass', 'ownertype'), ('bldgclass', 'subsidies_flag'), ('subsidies_flag', 'violations'), ('yearbuilt', 'residfar'), ('yearbuilt', 'violations'), ('yearbuilt', 'subsidies_flag'), ('yearbuilt', 'bldgclass'), ('unit_ratio', 'yearbuilt'), ('unit_ratio', 'bldgclass'), ('violations', 'residfar'), ('violations', 'landuse')]

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')

for cpd in best_model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
    
print best_model.local_independencies('violations')

for thenode in best_model.nodes():
    print best_model.active_trail_nodes(thenode)
# Out:
# CPD of bldgclass:
# +--------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | unit_ratio   | unit_ratio(0)        | unit_ratio(0)        | unit_ratio(0)         | unit_ratio(0)         | unit_ratio(0)         | unit_ratio(1)        | unit_ratio(1)         | unit_ratio(1)        | unit_ratio(1)        | unit_ratio(1)         | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)         | unit_ratio(2)       | unit_ratio(3)        | unit_ratio(3)        | unit_ratio(3)        | unit_ratio(3)        | unit_ratio(3)        | unit_ratio(4)        | unit_ratio(4)        | unit_ratio(4)        | unit_ratio(4)        | unit_ratio(4)        |
# +--------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | yearbuilt    | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)          | yearbuilt(3)          | yearbuilt(4)          | yearbuilt(0)         | yearbuilt(1)          | yearbuilt(2)         | yearbuilt(3)         | yearbuilt(4)          | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)          | yearbuilt(4)        | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)         | yearbuilt(4)         | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)         | yearbuilt(4)         |
# +--------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | bldgclass(0) | 0.008040131940626718 | 0.008656799776598716 | 0.0032742681047765792 | 0.009366391184573003  | 0.0015822784810126582 | 0.01362848589884985  | 0.022637795275590553  | 0.010328775094559208 | 0.014656144306651634 | 0.0007342143906020558 | 0.03718737724237266  | 0.0660024906600249   | 0.02437703141928494  | 0.037530864197530864  | 0.10925925925925926 | 0.15077183336857686  | 0.263573543928924    | 0.14391143911439114  | 0.07525870178739416  | 0.06998521439132578  | 0.44603825136612024  | 0.49423076923076925  | 0.3780701754385965   | 0.3707865168539326   | 0.09992006394884093  |
# +--------------+----------------------+----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | bldgclass
bldgclass(1)           | bldgclass(1)          | bldgclass(1)          | bldgclass(2)         | bldgclass(2)        | bldgclass(2)         | bldgclass(2)          | bldgclass(2)        | bldgclass(3)       | bldgclass(3)        | bldgclass(3)        | bldgclass(3)         | bldgclass(3)        | bldgclass(4)        | bldgclass(4)        | bldgclass(4)       | bldgclass(4)        | bldgclass(4)        | bldgclass(5)          | bldgclass(5)        | bldgclass(5)          | bldgclass(5)         | bldgclass(5)         |
# +-------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+----------------------+---------------------+----------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+-----------------------+---------------------+-----------------------+----------------------+----------------------+
# | yearbuilt         | yearbuilt(0)          | yearbuilt(1)         | yearbuilt(2)          | yearbuilt(3)         | yearbuilt(4)          | yearbuilt(0)          | yearbuilt(1)           | yearbuilt(2)           | yearbuilt(3)          | yearbuilt(4)          | yearbuilt(0)         | yearbuilt(1)        | yearbuilt(2)         | yearbuilt(3)          | yearbuilt(4)        | yearbuilt(0)       | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)         | yearbuilt(4)        | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)       | yearbuilt(3)        | yearbuilt(4)        | yearbuilt(0)          | yearbuilt(1)        | yearbuilt(2)          | yearbuilt(3)         | yearbuilt(4)         |
# +-------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+----------------------+---------------------+----------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+-----------------------+---------------------+-----------------------+----------------------+----------------------+
# | subsidies_flag(0) | 0.9996138996138996    | 0.9986244841815681   | 0.9988839285714286    | 0.9975429975429976   | 0.9982238010657194    | 0.9999306326304107    | 0.9995598591549296     | 0.9997287032013022     | 0.9997682502896872    | 0.9994469026548672    | 0.9877399733890895   | 0.9830051813471503  | 0.9806368655926178   | 0.9976053639846744    | 0.9693640397211071  | 0.9318801089918256 | 0.8979057591623036  | 0.9604449938195303  | 0.9600380589914367   | 0.6861626248216833  | 0.9137055837563451  | 0.868421052631579   | 0.9217391304347826 | 0.9333333333333333  | 0.7812337998963194  | 0.9964969011048235    | 0.99800796812749    | 0.9975200305227012    | 0.9950980392156863   | 0.9675925925925926   |
# +-------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+----------------------+---------------------+----------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+-----------------------+---------------------+-----------------------+----------------------+----------------------+
# | subsidies_flag(1) | 0.0003861003861003861 | 0.001375515818431912 | 0.0011160714285714285 | 0.002457002457002457 | 0.0017761989342806395 | 6.936736958934517e-05 | 0.00044014084507042255 | 0.00027129679869777537 | 0.0002317497103128621 | 0.0005530973451327434 | 0.012260026610910474 | 0.01699481865284974 | 0.019363134407382195 | 0.0023946360153256703 | 0.03063596027889288 | 0.0681198910081744 | 0.10209424083769633 | 0.03955500618046971 | 0.039961941008563276 | 0.31383737517831667 | 0.08629441624365482 | 0.13157894736842105 | 0.0782608695652174 | 0.06666666666666667 | 0.21876620010368067 | 0.0035030988951765024 | 0.00199203187250996 | 0.0024799694772987407 | 0.004901960784313725 | 0.032407407407407406 |
# +-------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+----------------------+---------------------+----------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+-----------------------+---------------------+-----------------------+----------------------+----------------------+
# CPD of ownertype:
# +--------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+
# | bldgclass    | bldgclass(0)          | bldgclass(1)          | bldgclass(2)           | bldgclass(3)         | bldgclass(4)           | bldgclass(5)          |
# +--------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+
# | ownertype(0) | 0.9951718810351488    | 0.9971689566661633    | 0.9937263102862371     | 0.8290468986384266   | 0.998390989541432      | 0.9969652381828215    |
# +--------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+
# | ownertype(1) | 0.0028968713789107765 | 0.0013966480446927375 | 0.0017862588768352721  | 0.02390317700453858  | 0.00040225261464199515 | 0.002391024462019496  |
# +--------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+
# | ownertype(2) | 0.000772499034376207  | 0.0012834063113392722 | 0.0038992724262623623  | 0.1443267776096823   | 0.00040225261464199515 | 9.196247930844215e-05 |
# +--------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+
# | ownertype(3) | 0.000772499034376207  | 0.0001132417333534652 | 0.0005663747658258179  | 0.000605143721633888 | 0.00040225261464199515 | 0.0004598123965422108 |
# +--------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+
# | ownertype(4) | 0.0003862495171881035 | 3.774724445115507e-05 | 2.1783644839454536e-05 | 0.002118003025718608 | 0.00040225261464199515 | 9.196247930844215e-05 |
# +--------------+-----------------------+-----------------------+------------------------+----------------------+------------------------+-----------------------+
# CPD of residfar:
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------+---------------------+---------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+---------------------+---------------------+
# | bldgclass   | bldgclass(0)        | bldgclass(0)        | bldgclass(0)        | bldgclass(0)        | bldgclass(0)        | bldgclass(0)        | bldgclass(0)        | bldgclass(0)  | bldgclass(0)        | bldgclass(0)  | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)         | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)       | bldgclass(1)         | bldgclass(2)         | bldgclass(2)        | bldgclass(2)         | bldgclass(2)        | bldgclass(2)        | bldgclass(2)         | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)        | bldgclass(3)        | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)        | bldgclass(4)         | bldgclass(4)  | bldgclass(4)        | bldgclass(4)        | bldgclass(4)         | bldgclass(5)         | bldgclass(5)         | bldgclass(5)        | bldgclass(5)        | bldgclass(5)         | bldgclass(5)        | bldgclass(5)         | bldgclass(5)         | bldgclass(5)        | bldgclass(5)        |
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------+---------------------+---------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+---------------------+---------------------+
# | violations  | violations(0)       | violations(0)       | violations(0)       | violations(0)       | violations(0)       | violations(1)       | violations(1)       | violations(1) | violations(1)       | violations(1) | violations(0)       | violations(0)       | violations(0)       | violations(0)       | violations(0)        | violations(1)       | violations(1)       | violations(1)       | violations(1)      | violations(1)        | violations(0)        | violations(0)       | violations(0)        | violations(0)       | violations(0)       | violations(1)        | violations(1)       | violations(1)       | violations(1)       | violations(1)        | violations(0)        | violations(0)        | violations(0)       | violations(0)       | violations(0)        | violations(1)        | violations(1)        | violations(1)        | violations(1)        | violations(1)       | violations(0)        | violations(0)       | violations(0)        | violations(0)       | violations(0)       | violations(1)        | violations(1) | violations(1)       | violations(1)       | violations(1)        | violations(0)        | violations(0)        | violations(0)       | violations(0)       | violations(0)        | violations(1)       | violations(1)        | violations(1)        | violations(1)       | violations(1)       |
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------+---------------------+---------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+---------------------+---------------------+
# | yearbuilt   | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)        | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)  | yearbuilt(3)        | yearbuilt(4)  | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)         | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)       | yearbuilt(4)         | yearbuilt(0)         | yearbuilt(1)        | yearbuilt(2)         | yearbuilt(3)        | yearbuilt(4)        | yearbuilt(0)         | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)         | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)         | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)         | yearbuilt(4)        | yearbuilt(0)         | yearbuilt(1)        | yearbuilt(2)         | yearbuilt(3)        | yearbuilt(4)        | yearbuilt(0)         | yearbuilt(1)  | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)         | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)         | yearbuilt(0)        | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)        | yearbuilt(4)        |
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------+---------------------+---------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+---------------------+---------------------+
# | residfar(0) | 0.13761829652996846 | 0.21835883171070933 | 0.13151927437641722 | 0.18796992481203006 | 0.0626118067978533  | 0.13333333333333333 | 0.14285714285714285 | 0.05          | 0.14285714285714285 | 0.1           | 0.04205842245029785 | 0.09734114465975664 | 0.06427168116755543 | 0.11121741210236785 | 0.057625145518044235 | 0.032719836400818   | 0.13559322033898305 | 0.08527131782945736 | 0.05               | 0.041666666666666664 | 0.029358770535241125 | 0.03267806995149349 | 0.034113773550393266 | 0.0508652333508128  | 0.01936822688494351 | 0.030275229357798167 | 0.02735229759299781 | 0.02442215438290449 | 0.0213903743315508  | 0.009950248756218905 | 0.017241379310344827 | 0.046296296296296294 | 0.04105571847507331 | 0.04905660377358491 | 0.017543859649122806 | 0.03614457831325301  | 0.007142857142857143 | 0.016877637130801686 | 0.017077798861480076 | 0.00974025974025974 | 0.010610079575596816 | 0.05128205128205128 | 0.027522935779816515 | 0.06666666666666667 | 0.01994134897360704 | 0.043478260869565216 | 0.2           | 0.08333333333333333 | 0.16666666666666666 | 0.017391304347826087 | 0.0518605332552007   | 0.059532246633593196 | 0.06900145924536169 | 0.09595959595959595 | 0.043478260869565216 | 0.03618421052631579 | 0.0594059405940594   | 0.04878048780487805  | 0.08333333333333333 | 0.06666666666666667 |
# +-------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------+---------------------+---------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+---------------------+---------------------+
# | residfar(1) | 0.17665615141955837 | 0.4242002781641168  | 0.48299319727891155 | 0.3634085213032581  | 0.03220035778175313 | 0.2                 | 0.5                 | 0.45          | 0.21428571428571427 | 0.1           | 0.09280126318811455 | 0.32041460117169895 | 0.31855178220600616 | 0.2795981822530495  | 0.11816065192083819  | 0.07566462167689161 | 0.3728813559322034  | 0.2868217054263566  | 0.2785714285714286 | 0.14583333333333334  | 0.03434022257551669
------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------+---------------------+---------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+---------------------+---------------------+
# CPD of yearbuilt:
# +--------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | unit_ratio   | unit_ratio(0)       | unit_ratio(1)       | unit_ratio(2)       | unit_ratio(3)       | unit_ratio(4)       |
# +--------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | yearbuilt(0) | 0.4607709606917741  | 0.45356734343723193 | 0.43277573008222286 | 0.44124789837474315 | 0.4604599873976055  |
# +--------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | yearbuilt(1) | 0.11326850590732    | 0.10877180440377467 | 0.09078537000283526 | 0.09415281150756585 | 0.08112791430371771 |
# +--------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | yearbuilt(2) | 0.32875106901903645 | 0.24553188447240493 | 0.20907286645874681 | 0.17672333271062957 | 0.17879647132955262 |
# +--------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | yearbuilt(3) | 0.05733109499223971 | 0.09493851873034029 | 0.11454493904167848 | 0.09882308985615543 | 0.08333333333333333 |
# +--------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | yearbuilt(4) | 0.03987836938962972 | 0.09719044895624822 | 0.15282109441451658 | 0.18905286755090603 | 0.1962822936357908  |
# +--------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# CPD of unit_ratio:
# +---------------+-----------+
# | unit_ratio(0) | 0.335049  |
# +---------------+-----------+
# | unit_ratio(1) | 0.296892  |
# +---------------+-----------+
# | unit_ratio(2) | 0.187134  |
# +---------------+-----------+
# | unit_ratio(3) | 0.11359   |
# +---------------+-----------+
# | unit_ratio(4) | 0.0673346 |
# +---------------+-----------+
# CPD of violations:
# +----------------+----------------------+----------------------+----------------------+---------------------+----------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------------------+---------------------+--------------------+---------------------+---------------------+-------------------+-------------------+-------------------+-------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+--------------------+----------------------+---------------------+-------------------+---------------------+---------------------+--------------------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+-------------------+---------------------+-------------------+-------------------+
# | bldgclass      | bldgclass(0)         | bldgclass(0)         | bldgclass(0)         | bldgclass(0)        | bldgclass(0)         | bldgclass(0)      | bldgclass(0)      | bldgclass(0)      | bldgclass(0)      | bldgclass(0)      | bldgclass(1)         | bldgclass(1)        | bldgclass(1)       | bldgclass(1)        | bldgclass(1)        | bldgclass(1)      | bldgclass(1)      | bldgclass(1)      | bldgclass(1)      | bldgclass(1)      | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)       | bldgclass(2)        | bldgclass(2)       | bldgclass(2)        | bldgclass(2)       | bldgclass(3)        | bldgclass(3)        | bldgclass(3)       | bldgclass(3)       | bldgclass(3)        | bldgclass(3)        | bldgclass(3)      | bldgclass(3)        | bldgclass(3)        | bldgclass(3)      | bldgclass(4)       | bldgclass(4)         | bldgclass(4)        | bldgclass(4)      | bldgclass(4)        | bldgclass(4)        | bldgclass(4)       | bldgclass(4)      | bldgclass(4)      | bldgclass(4)       | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)       | bldgclass(5)      | bldgclass(5)        | bldgclass(5)      | bldgclass(5)      |
# +----------------+----------------------+----------------------+----------------------+---------------------+----------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------------------+---------------------+--------------------+---------------------+---------------------+-------------------+-------------------+-------------------+-------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+--------------------+----------------------+---------------------+-------------------+---------------------+---------------------+--------------------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+-------------------+---------------------+-------------------+-------------------+
# | subsidies_flag | subsidies_flag(0)    | subsidies_flag(0)    | subsidies_flag(0)    | subsidies_flag(0)   | subsidies_flag(0)    | subsidies_flag(1) | subsidies_flag(1) | subsidies_flag(1) | subsidies_flag(1) | subsidies_flag(1) | subsidies_flag(0)    | subsidies_flag(0)   | subsidies_flag(0)  | subsidies_flag(0)   | subsidies_flag(0)   | subsidies_flag(1) | subsidies_flag(1) | subsidies_flag(1) | subsidies_flag(1) | subsidies_flag(1) | subsidies_flag(0)   | subsidies_flag(0)   | subsidies_flag(0)   | subsidies_flag(0)   | subsidies_flag(0)   | subsidies_flag(1)  | subsidies_flag(1)   | subsidies_flag(1)  | subsidies_flag(1)   | subsidies_flag(1)  | subsidies_flag(0)   | subsidies_flag(0)   | subsidies_flag(0)  | subsidies_flag(0)  | subsidies_flag(0)   | subsidies_flag(1)   | subsidies_flag(1) | subsidies_flag(1)   | subsidies_flag(1)   | subsidies_flag(1) | subsidies_flag(0)  | subsidies_flag(0)    | subsidies_flag(0)   | subsidies_flag(0) | subsidies_flag(0)   | subsidies_flag(1)   | subsidies_flag(1)  | subsidies_flag(1) | subsidies_flag(1) | subsidies_flag(1)  | subsidies_flag(0)   | subsidies_flag(0)   | subsidies_flag(0)   | subsidies_flag(0)   | subsidies_flag(0)   | subsidies_flag(1)  | subsidies_flag(1) | subsidies_flag(1)   | subsidies_flag(1) | subsidies_flag(1) |
# +----------------+----------------------+----------------------+----------------------+---------------------+----------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------------------+---------------------+--------------------+---------------------+---------------------+-------------------+-------------------+-------------------+-------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+--------------------+----------------------+---------------------+-------------------+---------------------+---------------------+--------------------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+-------------------+---------------------+-------------------+-------------------+
# | yearbuilt      | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)        | yearbuilt(4)         | yearbuilt(0)      | yearbuilt(1)      | yearbuilt(2)      | yearbuilt(3)      | yearbuilt(4)      | yearbuilt(0)         | yearbuilt(1)        | yearbuilt(2)       | yearbuilt(3)        | yearbuilt(4)        | yearbuilt(0)      | yearbuilt(1)      | yearbuilt(2)      | yearbuilt(3)      | yearbuilt(4)      | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)        | yearbuilt(0)       | yearbuilt(1)        | yearbuilt(2)       | yearbuilt(3)        | yearbuilt(4)       | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)       | yearbuilt(3)       | yearbuilt(4)        | yearbuilt(0)        | yearbuilt(1)      | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)      | yearbuilt(0)       | yearbuilt(1)         | yearbuilt(2)        | yearbuilt(3)      | yearbuilt(4)        | yearbuilt(0)        | yearbuilt(1)       | yearbuilt(2)      | yearbuilt(3)      | yearbuilt(4)       | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)        | yearbuilt(0)       | yearbuilt(1)      | yearbuilt(2)        | yearbuilt(3)      | yearbuilt(4)      |
# +----------------+----------------------+----------------------+----------------------+---------------------+----------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------------------+---------------------+--------------------+---------------------+---------------------+-------------------+-------------------+-------------------+-------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+--------------------+----------------------+---------------------+-------------------+---------------------+---------------------+--------------------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+-------------------+---------------------+-------------------+-------------------+
# | violations(0)  | 0.977992277992278    | 0.984869325997249    | 0.9810267857142857   | 0.972972972972973   | 0.9875666074600356   | 0.5               | 0.5               | 0.5               | 0.5               | 0.5               | 0.9662874583795783   | 0.9753521126760564  | 0.9658166033640803 | 0.9682502896871379  | 0.9485619469026548  | 0.5               | 0.5               | 0.5               | 0.5               | 0.5               | 0.905229229807091   | 0.8237774030354131  | 0.8412771864877372  | 0.9136276391554703  | 0.929396382654173   | 0.1969111969111969 | 0.08433734939759036 | 0.0933852140077821 | 0.16666666666666666 | 0.4794520547945205 | 0.8279883381924198  | 0.29941860465116277 | 0.4267352185089974 | 0.5198019801980198 | 0.7468879668049793  | 0.15384615384615385 | 0.075             | 0.21212121212121213 | 0.06976744186046512 | 0.167420814479638 | 0.9556786703601108 | 0.9705882352941176   | 0.9158878504672897  | 0.8               | 0.8919098143236074  | 0.8571428571428571  | 0.6666666666666666 | 0.9               | 0.5               | 0.8463356973995272 | 0.9194376858610436  | 0.9361702127659575  | 0.9162523900573614  | 0.9558823529411765  | 0.9428571428571428  | 0.7142857142857143 | 0.25              | 0.21428571428571427 | 0.5               | 0.875             |
# +----------------+----------------------+----------------------+----------------------+---------------------+----------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------------------+---------------------+--------------------+---------------------+---------------------+-------------------+-------------------+-------------------+-------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+--------------------+----------------------+---------------------+-------------------+---------------------+---------------------+--------------------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+-------------------+---------------------+-------------------+-------------------+
# | violations(1)  | 0.022007722007722007 | 0.015130674002751032 | 0.018973214285714284 | 0.02702702702702703 | 0.012433392539964476 | 0.5               | 0.5               | 0.5               | 0.5               | 0.5               | 0.033712541620421754 | 0.02464788732394366 | 0.0341833966359197 | 0.03174971031286211 | 0.05143805309734513 | 0.5               | 0.5               | 0.5               | 0.5               | 0.5               | 0.09477077019290903 | 0.17622259696458684 | 0.15872281351226283 | 0.08637236084452975 | 0.07060361734582697 | 0.803088803088803  | 0.9156626506024096  | 0.9066147859922179 | 0.8333333333333334  | 0.5205479452054794 | 0.17201166180758018 | 0.7005813953488372  | 0.5732647814910026 | 0.4801980198019802 | 0.25311203319502074 | 0.8461538461538461  | 0.925             | 0.7878787878787878  | 0.9302325581395349  | 0.832579185520362 | 0.0443213296398892 | 0.029411764705882353 | 0.08411214953271028 | 0.2               | 0.10809018567639257 | 0.14285714285714285 | 0.3333333333333333 | 0.1               | 0.5               | 0.1536643026004728 | 0.08056231413895648 | 0.06382978723404255 | 0.08374760994263862 | 0.04411764705882353 | 0.05714285714285714 | 0.2857142857142857 | 0.75              | 0.7857142857142857  | 0.5               | 0.125             |
# +----------------+----------------------+----------------------+----------------------+---------------------+----------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------------------+---------------------+--------------------+---------------------+---------------------+-------------------+-------------------+-------------------+-------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+--------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+--------------------+----------------------+---------------------+-------------------+---------------------+---------------------+--------------------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+-------------------+---------------------+-------------------+-------------------+
# CPD of landuse:
# +------------+------------------------+---------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+
# | bldgclass  | bldgclass(0)           | bldgclass(0)        | bldgclass(1)          | bldgclass(1)          | bldgclass(2)          | bldgclass(2)           | bldgclass(3)          | bldgclass(3)          | bldgclass(4)           | bldgclass(4)          | bldgclass(5)         | bldgclass(5)          |
# +------------+------------------------+---------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+
# | violations | violations(0)          | violations(1)       | violations(0)         | violations(1)         | violations(0)         | violations(1)          | violations(0)         | violations(1)         | violations(0)          | violations(1)         | violations(0)        | violations(1)         |
# +------------+------------------------+---------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+
# | landuse(0) | 0.9994093325457767     | 0.9705882352941176  | 0.9998828033440113    | 0.9966555183946488    | 2.503191569250795e-05 | 0.00016778523489932885 | 0.0006053268765133172 | 0.0006038647342995169 | 0.00044863167339614175 | 0.0038461538461538464 | 9.99000999000999e-05 | 0.0011534025374855825 |
# +------------+------------------------+---------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+
# | landuse(1) | 0.00019688915140775743 | 0.00980392156862745 | 3.906555199624971e-05 | 0.0011148272017837235 | 0.9799244036146086    | 0.9157718120805369     | 0.0006053268765133172 | 0.0006038647342995169 | 0.8649618663077613     | 0.8307692307692308    | 9.99000999000999e-05 | 0.0011534025374855825 |
# +------------+------------------------+---------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+
# | landuse(2) | 0.00019688915140775743 | 0.00980392156862745 | 3.906555199624971e-05 | 0.0011148272017837235 | 2.503191569250795e-05 | 0.00016778523489932885 | 0.8414043583535109    | 0.8919082125603864    | 0.1341408703454464     | 0.1576923076923077    | 9.99000999000999e-05 | 0.0011534025374855825 |
# +------------+------------------------+---------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+
# | landuse(3) | 0.00019688915140775743 | 0.00980392156862745 | 3.906555199624971e-05 | 0.0011148272017837235 | 0.020025532554006357  | 0.08389261744966443    | 0.15738498789346247   | 0.1068840579710145    | 0.00044863167339614175 | 0.007692307692307693  | 0.9997002997002997   | 0.9965397923875432    |
# +------------+------------------------+---------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+-----------------------+
# (violations _|_ unit_ratio, ownertype | subsidies_flag, yearbuilt, bldgclass)
# {'bldgclass': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'subsidies_flag': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'ownertype': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'residfar': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'yearbuilt': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'unit_ratio': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'violations': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'landuse': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')
test_x = data18test.drop(columns=['violations'])
predicted_test = temp_predict(best_model, test_x)
print "Out of sample:",(data18test.loc[:,'violations']==predicted_test['violations']).mean()
# Out:
# WARNING:root:Replacing existing CPD for bldgclass
# WARNING:root:Replacing existing CPD for subsidies_flag
# WARNING:root:Replacing existing CPD for ownertype
# WARNING:root:Replacing existing CPD for residfar
# WARNING:root:Replacing existing CPD for yearbuilt
# WARNING:root:Replacing existing CPD for unit_ratio
# WARNING:root:Replacing existing CPD for violations
# WARNING:root:Replacing existing CPD for landuse
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# Out of sample: 0.9088438840062837
