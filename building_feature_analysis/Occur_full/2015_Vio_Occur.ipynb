# %%
import numpy as np
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5a492aa7-2ebc-4414-af02-7b555c5ebb3d" name="files[]" multiple disabled />
#      <output id="result-5a492aa7-2ebc-4414-af02-7b555c5ebb3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data15smaller_0.csv to data15smaller_0 (1).csv

# %%
data18smaller = pd.read_csv("data15smaller_0.csv", low_memory = False, dtype = {'subsidies_flag':"int64"})

# %%
# !pip install pgmpy==0.1.7
from pgmpy.estimators import HillClimbSearch, BicScore, BayesianEstimator
from pgmpy.models import BayesianModel
from sklearn.model_selection import train_test_split
from pgmpy.inference import VariableElimination
# Out:
# Collecting pgmpy==0.1.7
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python2.7/dist-packages (from pgmpy==0.1.7) (1.2.1)
# Collecting networkx<1.12,>=1.11 (from pgmpy==0.1.7)
#   Using cached https://files.pythonhosted.org/packages/d3/2c/e473e54afc9fae58dfa97066ef6709a7e35a1dd1c28c5a3842989322be00/networkx-1.11-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python2.7/dist-packages (from pgmpy==0.1.7) (1.16.3)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python2.7/dist-packages (from networkx<1.12,>=1.11->pgmpy==0.1.7) (4.4.0)
# Installing collected packages: networkx, pgmpy
#   Found existing installation: networkx 2.2
#     Can't uninstall 'networkx'. No files were found to uninstall.
# Successfully installed networkx-1.11 pgmpy-0.1.7

# %%
data18train, data18test = train_test_split(data18smaller,random_state=9,test_size=0.2)
hc = HillClimbSearch(data18train, scoring_method=BicScore(data18train))
best_model = hc.estimate()
print(best_model.edges())
# Out:
# [('bldgclass', 'residfar'), ('bldgclass', 'yearbuilt'), ('bldgclass', 'violations'), ('bldgclass', 'landuse'), ('bldgclass', 'ownertype'), ('subsidies_flag', 'residfar'), ('subsidies_flag', 'violations'), ('subsidies_flag', 'bldgclass'), ('subsidies_flag', 'affordability_flag'), ('residfar', 'violations'), ('residfar', 'landuse'), ('violations', 'yearbuilt'), ('violations', 'landuse'), ('violations', 'ownertype'), ('violations', 'unitsres'), ('landuse', 'unitsres')]

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')

for cpd in best_model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
    
print best_model.local_independencies('violations')

for thenode in best_model.nodes():
    print best_model.active_trail_nodes(thenode)
# Out:
# CPD of unitsres:
# +-------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+
# | landuse     | landuse(0)             | landuse(0)            | landuse(1)             | landuse(1)           | landuse(2)            | landuse(2)             | landuse(3)            | landuse(3)             |
# +-------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+
# | violations  | violations(0)          | violations(1)         | violations(0)          | violations(1)        | violations(0)         | violations(1)          | violations(0)         | violations(1)          |
# +-------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+
# | unitsres(0) | 0.9999549929676512     | 0.9987063389391979    | 0.9999499029369403     | 0.9997189827174371   | 0.9949918986595964    | 0.9571066484694872     | 0.99982530462506      | 0.9915513212295524     |
# +-------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+
# | unitsres(1) | 1.1251758087201125e-05 | 0.0003234152652005175 | 1.2524265764919531e-05 | 7.02543206407194e-05 | 0.0014729709824716454 | 0.025151101579255215   | 4.367384373498712e-05 | 0.00017975912277548085 |
# +-------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+
# | unitsres(2) | 1.1251758087201125e-05 | 0.0003234152652005175 | 1.2524265764919531e-05 | 7.02543206407194e-05 | 0.0007364854912358227 | 0.004679274712419575   | 4.367384373498712e-05 | 0.00017975912277548085 |
# +-------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+
# | unitsres(3) | 1.1251758087201125e-05 | 0.0003234152652005175 | 1.2524265764919531e-05 | 7.02543206407194e-05 | 0.0014729709824716454 | 0.00019496977968414895 | 4.367384373498712e-05 | 0.007909401402121157   |
# +-------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+
# | unitsres(4) | 1.1251758087201125e-05 | 0.0003234152652005175 | 1.2524265764919531e-05 | 7.02543206407194e-05 | 0.0013256738842244808 | 0.012868005459153831   | 4.367384373498712e-05 | 0.00017975912277548085 |
# +-------------+------------------------+-----------------------+------------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+
# CPD of bldgclass:
# +----------------+----------------------+------------------------+
# | subsidies_flag | subsidies_flag(0)    | subsidies_flag(1)      |
# +----------------+----------------------+------------------------+
# | bldgclass(0)   | 0.11355003255914912  | 0.00019011406844106463 |
# +----------------+----------------------+------------------------+
# | bldgclass(1)   | 0.3022981332754504   | 0.00019011406844106463 |
# +----------------+----------------------+------------------------+
# | bldgclass(2)   | 0.425104912813834    | 0.49049429657794674    |
# +----------------+----------------------+------------------------+
# | bldgclass(3)   | 0.05330656247738948  | 0.30304182509505706    |
# +----------------+----------------------+------------------------+
# | bldgclass(4)   | 0.017595506837421317 | 0.19334600760456275    |
# +----------------+----------------------+------------------------+
# | bldgclass(5)   | 0.08814485203675566  | 0.01273764258555133    |
# +----------------+----------------------+------------------------+
# CPD of subsidies_flag:
# +-------------------+-----------+
# | subsidies_flag(0) | 0.976787  |
# +-------------------+-----------+
# | subsidies_flag(1) | 0.0232126 |
# +-------------------+-----------+
# CPD of ownertype:
# +--------------+-----------------------+--------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+
# | bldgclass    | bldgclass(0)          | bldgclass(0)       | bldgclass(1)          | bldgclass(1)          | bldgclass(2)           | bldgclass(2)          | bldgclass(3)          | bldgclass(3)          | bldgclass(4)          | bldgclass(4)         | bldgclass(5)          | bldgclass(5)          |
# +--------------+-----------------------+--------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+
# | violations   | violations(0)         | violations(1)      | violations(0)         | violations(1)         | violations(0)          | violations(1)         | violations(0)         | violations(1)         | violations(0)         | violations(1)        | violations(0)         | violations(1)         |
# +--------------+-----------------------+--------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+
# | ownertype(0) | 0.9910823356950892    | 0.9910873440285205 | 0.9972793134541836    | 0.9980283911671924    | 0.9910172917134517     | 0.9944647201946472    | 0.8107035313441008    | 0.9255424063116371    | 0.9980778471888515    | 0.9350132625994695   | 0.9959807971419002    | 0.9975801572897761    |
# +--------------+-----------------------+--------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+
# | ownertype(1) | 0.00305399462496946   | 0.0035650623885918 | 0.0015702248064425857 | 0.0007886435331230284 | 0.0021832971529805126  | 0.002615571776155718  | 0.019846701341363262  | 0.04043392504930966   | 0.0007208073041806823 | 0.001326259946949602 | 0.0030702244054929104 | 0.0006049606775559589 |
# +--------------+-----------------------+--------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+
# | ownertype(2) | 0.005130710969948693  | 0.0017825311942959 | 0.0009017132551848512 | 0.0003943217665615142 | 0.004765825785363176   | 0.0018856447688564476 | 0.16438543662742952   | 0.027777777777777776  | 0.0004805382027871216 | 0.001326259946949602 | 5.582226191805292e-05 | 0.0006049606775559589 |
# +--------------+-----------------------+--------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+
# | ownertype(3) | 0.000610798924993892  | 0.0017825311942959 | 0.0002332017039271167 | 0.0003943217665615142 | 0.0020211093644733886  | 0.0009732360097323601 | 0.0032849712565015056 | 0.004437869822485207  | 0.0004805382027871216 | 0.0610079575596817   | 0.0008373339287707938 | 0.0006049606775559589 |
# +--------------+-----------------------+--------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+
# | ownertype(4) | 0.0001221597849987784 | 0.0017825311942959 | 1.554678026180778e-05 | 0.0003943217665615142 | 1.2475983731317214e-05 | 6.082725060827251e-05 | 0.0017793594306049821 | 0.0018080210387902695 | 0.0002402691013935608 | 0.001326259946949602 | 5.582226191805292e-05 | 0.0006049606775559589 |
# +--------------+-----------------------+--------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+-----------------------+-----------------------+
# CPD of residfar:
# +----------------+-----------------------+-------------------+-----------------------+-------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | bldgclass      | bldgclass(0)          | bldgclass(0)      | bldgclass(1)          | bldgclass(1)      | bldgclass(2)         | bldgclass(2)          | bldgclass(3)        | bldgclass(3)         | bldgclass(4)         | bldgclass(4)         | bldgclass(5)         | bldgclass(5)         |
# +----------------+-----------------------+-------------------+-----------------------+-------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | subsidies_flag | subsidies_flag(0)     | subsidies_flag(1) | subsidies_flag(0)     | subsidies_flag(1) | subsidies_flag(0)    | subsidies_flag(1)     | subsidies_flag(0)   | subsidies_flag(1)    | subsidies_flag(0)    | subsidies_flag(1)    | subsidies_flag(0)    | subsidies_flag(1)    |
# +----------------+-----------------------+-------------------+-----------------------+-------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | residfar(0)    | 0.8982598654083542    | 0.25              | 0.8313737808891283    | 0.25              | 0.5880075311938219   | 0.2067363530778165    | 0.1810703078619286  | 0.1308703819661866   | 0.6217257318952234   | 0.453921568627451    | 0.45919466529879455  | 0.24285714285714285  |
# +----------------+-----------------------+-------------------+-----------------------+-------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | residfar(1)    | 0.095169832357743     | 0.25              | 0.16397415185783523   | 0.25              | 0.37000712697720434  | 0.7142857142857143    | 0.5675515223475532  | 0.7107075767063243   | 0.32845403184386235  | 0.5127450980392156   | 0.4812516029751218   | 0.6857142857142857   |
# +----------------+-----------------------+-------------------+-----------------------+-------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | residfar(2)    | 0.004340381475729702  | 0.25              | 0.004322982109734937  | 0.25              | 0.027880309332085226 | 0.07510646535036779   | 0.12195742515477907 | 0.12648716343143393  | 0.030816640986132512 | 0.023529411764705882 | 0.031033598358553474 | 0.05714285714285714  |
# +----------------+-----------------------+-------------------+-----------------------+-------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | residfar(3)    | 0.0022299207581730576 | 0.25              | 0.0003290851433016215 | 0.25              | 0.014105032496888596 | 0.0038714672861014324 | 0.12942074463573913 | 0.031934877896055106 | 0.019003595274781716 | 0.00980392156862745  | 0.028520133367530134 | 0.014285714285714285 |
# +----------------+-----------------------+-------------------+-----------------------+-------------------+----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# CPD of yearbuilt:
# +--------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+----------------------+----------------------+----------------------+----------------------+-----------------------+-----------------------+
# | bldgclass    | bldgclass(0)          | bldgclass(0)          | bldgclass(1)          | bldgclass(1)          | bldgclass(2)          | bldgclass(2)           | bldgclass(3)         | bldgclass(3)         | bldgclass(4)         | bldgclass(4)         | bldgclass(5)          | bldgclass(5)          |
# +--------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+----------------------+----------------------+----------------------+----------------------+-----------------------+-----------------------+
# | violations   | violations(0)         | violations(1)         | violations(0)         | violations(1)         | violations(0)         | violations(1)          | violations(0)        | violations(1)        | violations(0)        | violations(1)        | violations(0)         | violations(1)         |
# +--------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+----------------------+----------------------+----------------------+----------------------+-----------------------+-----------------------+
# | yearbuilt(0) | 0.0009773976786805131 | 0.0017921146953405018 | 0.0007618277647351482 | 0.0007895775759968417 | 0.0022831904779728263 | 0.00012167670499482874 | 0.024784335204710392 | 0.000493339911198816 | 0.021880259677807164 | 0.009320905459387484 | 0.0010049690134554185 | 0.0006060606060606061 |
# +--------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+----------------------+----------------------+----------------------+----------------------+-----------------------+-----------------------+
# | yearbuilt(1) | 0.9990226023213195    | 0.9982078853046595    | 0.9992381722352649    | 0.9992104224240032    | 0.9977168095220271    | 0.9998783232950051     | 0.9752156647952896   | 0.9995066600888012   | 0.9781197403221928   | 0.9906790945406125   | 0.9989950309865446    | 0.9993939393939394    |
# +--------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+----------------------+----------------------+----------------------+----------------------+-----------------------+-----------------------+
# CPD of affordability_flag:
# +-----------------------+------------------------+-----------------------+
# | subsidies_flag        | subsidies_flag(0)      | subsidies_flag(1)     |
# +-----------------------+------------------------+-----------------------+
# | affordability_flag(0) | 0.9999683449853934     | 0.9689996196272347    |
# +-----------------------+------------------------+-----------------------+
# | affordability_flag(1) | 4.522144943789738e-06  | 0.0005705591479650057 |
# +-----------------------+------------------------+-----------------------+
# | affordability_flag(2) | 4.522144943789738e-06  | 0.001901863826550019  |
# +-----------------------+------------------------+-----------------------+
# | affordability_flag(3) | 2.2610724718948693e-05 | 0.028527957398250287  |
# +-----------------------+------------------------+-----------------------+
# CPD of violations:
# +----------------+----------------------+-------------------+----------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+-------------------+---------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+-------------------+---------------------+-------------------+-------------------+---------------------+--------------------+---------------------+-------------------+---------------------+-------------------+
# | bldgclass      | bldgclass(0)         | bldgclass(0)      | bldgclass(0)         | bldgclass(0)      | bldgclass(0)        | bldgclass(0)      | bldgclass(0)         | bldgclass(0)      | bldgclass(1)        | bldgclass(1)      | bldgclass(1)        | bldgclass(1)      | bldgclass(1)        | bldgclass(1)      | bldgclass(1)         | bldgclass(1)      | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)       | bldgclass(2)        | bldgclass(3)        | bldgclass(3)       | bldgclass(3)       | bldgclass(3)        | bldgclass(3)       | bldgclass(3)        | bldgclass(3)        | bldgclass(3)        | bldgclass(4)        | bldgclass(4)        | bldgclass(4)      | bldgclass(4)        | bldgclass(4)        | bldgclass(4)      | bldgclass(4)      | bldgclass(4)        | bldgclass(5)      | bldgclass(5)      | bldgclass(5)        | bldgclass(5)       | bldgclass(5)        | bldgclass(5)      | bldgclass(5)        | bldgclass(5)      |
# +----------------+----------------------+-------------------+----------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+-------------------+---------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+-------------------+---------------------+-------------------+-------------------+---------------------+--------------------+---------------------+-------------------+---------------------+-------------------+
# | residfar       | residfar(0)          | residfar(0)       | residfar(1)          | residfar(1)       | residfar(2)         | residfar(2)       | residfar(3)          | residfar(3)       | residfar(0)         | residfar(0)       | residfar(1)         | residfar(1)       | residfar(2)         | residfar(2)       | residfar(3)          | residfar(3)       | residfar(0)         | residfar(0)         | residfar(1)         | residfar(1)         | residfar(2)         | residfar(2)         | residfar(3)        | residfar(3)         | residfar(0)         | residfar(0)        | residfar(1)        | residfar(1)         | residfar(2)        | residfar(2)         | residfar(3)         | residfar(3)         | residfar(0)         | residfar(0)         | residfar(1)       | residfar(1)         | residfar(2)         | residfar(2)       | residfar(3)       | residfar(3)         | residfar(0)       | residfar(0)       | residfar(1)         | residfar(1)        | residfar(2)         | residfar(2)       | residfar(3)         | residfar(3)       |
# +----------------+----------------------+-------------------+----------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+-------------------+---------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+-------------------+---------------------+-------------------+-------------------+---------------------+--------------------+---------------------+-------------------+---------------------+-------------------+
# | subsidies_flag | subsidies_flag(0)    | subsidies_flag(1) | subsidies_flag(0)    | subsidies_flag(1) | subsidies_flag(0)   | subsidies_flag(1) | subsidies_flag(0)    | subsidies_flag(1) | subsidies_flag(0)   | subsidies_flag(1) | subsidies_flag(0)   | subsidies_flag(1) | subsidies_flag(0)   | subsidies_flag(1) | subsidies_flag(0)    | subsidies_flag(1) | subsidies_flag(0)   | subsidies_flag(1)   | subsidies_flag(0)   | subsidies_flag(1)   | subsidies_flag(0)   | subsidies_flag(1)   | subsidies_flag(0)  | subsidies_flag(1)   | subsidies_flag(0)   | subsidies_flag(1)  | subsidies_flag(0)  | subsidies_flag(1)   | subsidies_flag(0)  | subsidies_flag(1)   | subsidies_flag(0)   | subsidies_flag(1)   | subsidies_flag(0)   | subsidies_flag(1)   | subsidies_flag(0) | subsidies_flag(1)   | subsidies_flag(0)   | subsidies_flag(1) | subsidies_flag(0) | subsidies_flag(1)   | subsidies_flag(0) | subsidies_flag(1) | subsidies_flag(0)   | subsidies_flag(1)  | subsidies_flag(0)   | subsidies_flag(1) | subsidies_flag(0)   | subsidies_flag(1) |
# +----------------+----------------------+-------------------+----------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+-------------------+---------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+-------------------+---------------------+-------------------+-------------------+---------------------+--------------------+---------------------+-------------------+---------------------+-------------------+
# | violations(0)  | 0.9777029123631367   | 0.5               | 0.9782517774989544   | 0.5               | 0.9636363636363636  | 0.5               | 0.9824561403508771   | 0.5               | 0.9637459517812162  | 0.5               | 0.9541183982486545  | 0.5               | 0.9448275862068966  | 0.5               | 0.9565217391304348   | 0.5               | 0.9007579731905425  | 0.41682242990654206 | 0.7732355900531839  | 0.24052004333694474 | 0.6529366895499619  | 0.15384615384615385 | 0.7920120572720422 | 0.6363636363636364  | 0.6067415730337079  | 0.3523809523809524 | 0.5495293590318243 | 0.13556338028169015 | 0.5545517720639332 | 0.15270935960591134 | 0.8271119842829077  | 0.28846153846153844 | 0.8835672997522709  | 0.9310344827586207  | 0.8484375         | 0.5858778625954199  | 0.859504132231405   | 0.8               | 0.88              | 0.9090909090909091  | 0.935328940020105 | 0.5               | 0.9019503357135245  | 0.4897959183673469 | 0.8877887788778878  | 0.4               | 0.9084380610412927  | 0.5               |
# +----------------+----------------------+-------------------+----------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+-------------------+---------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+-------------------+---------------------+-------------------+-------------------+---------------------+--------------------+---------------------+-------------------+---------------------+-------------------+
# | violations(1)  | 0.022297087636863337 | 0.5               | 0.021748222501045588 | 0.5               | 0.03636363636363636 | 0.5               | 0.017543859649122806 | 0.5               | 0.03625404821878374 | 0.5               | 0.04588160175134543 | 0.5               | 0.05517241379310345 | 0.5               | 0.043478260869565216 | 0.5               | 0.09924202680945748 | 0.5831775700934579  | 0.22676440994681615 | 0.7594799566630552  | 0.34706331045003813 | 0.8461538461538461  | 0.2079879427279578 | 0.36363636363636365 | 0.39325842696629215 | 0.6476190476190476 | 0.4504706409681757 | 0.8644366197183099  | 0.4454482279360667 | 0.8472906403940886  | 0.17288801571709234 | 0.7115384615384616  | 0.11643270024772914 | 0.06896551724137931 | 0.1515625         | 0.41412213740458015 | 0.14049586776859505 | 0.2               | 0.12              | 0.09090909090909091 | 0.064671059979895 | 0.5               | 0.09804966428647555 | 0.5102040816326531 | 0.11221122112211221 | 0.6               | 0.09156193895870736 | 0.5               |
# +----------------+----------------------+-------------------+----------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+-------------------+---------------------+-------------------+---------------------+-------------------+----------------------+-------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+---------------------+---------------------+-------------------+-------------------+---------------------+-------------------+-------------------+---------------------+--------------------+---------------------+-------------------+---------------------+-------------------+
# CPD of landuse:
# +------------+-----------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+---------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------+---------------+---------------+------------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+--------------------+-----------------------+----------------------+
# | bldgclass  | bldgclass(0)          | bldgclass(0)         | bldgclass(0)          | bldgclass(0)        | bldgclass(0)         | bldgclass(0)        | bldgclass(0)        | bldgclass(0)  | bldgclass(1)           | bldgclass(1)          | bldgclass(1)          | bldgclass(1)         | bldgclass(1)          | bldgclass(1)        | bldgclass(1)  | bldgclass(1)  | bldgclass(2)           | bldgclass(2)           | bldgclass(2)         | bldgclass(2)           | bldgclass(2)          | bldgclass(2)          | bldgclass(2)          | bldgclass(2)          | bldgclass(3)          | bldgclass(3)          | bldgclass(3)          | bldgclass(3)           | bldgclass(3)          | bldgclass(3)         | bldgclass(3)  | bldgclass(3)          | bldgclass(4)          | bldgclass(4)          | bldgclass(4)          | bldgclass(4)         | bldgclass(4)         | bldgclass(4)         | bldgclass(4)        | bldgclass(4)        | bldgclass(5)           | bldgclass(5)         | bldgclass(5)           | bldgclass(5)          | bldgclass(5)          | bldgclass(5)       | bldgclass(5)          | bldgclass(5)         |
# +------------+-----------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+---------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------+---------------+---------------+------------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+--------------------+-----------------------+----------------------+
# | residfar   | residfar(0)           | residfar(0)          | residfar(1)           | residfar(1)         | residfar(2)          | residfar(2)         | residfar(3)         | residfar(3)   | residfar(0)            | residfar(0)           | residfar(1)           | residfar(1)          | residfar(2)           | residfar(2)         | residfar(3)   | residfar(3)   | residfar(0)            | residfar(0)            | residfar(1)          | residfar(1)            | residfar(2)           | residfar(2)           | residfar(3)           | residfar(3)           | residfar(0)           | residfar(0)           | residfar(1)           | residfar(1)            | residfar(2)           | residfar(2)          | residfar(3)   | residfar(3)           | residfar(0)           | residfar(0)           | residfar(1)           | residfar(1)          | residfar(2)          | residfar(2)          | residfar(3)         | residfar(3)         | residfar(0)            | residfar(0)          | residfar(1)            | residfar(1)           | residfar(2)           | residfar(2)        | residfar(3)           | residfar(3)          |
# +------------+-----------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+---------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------+---------------+---------------+------------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+--------------------+-----------------------+----------------------+
# | violations | violations(0)         | violations(1)        | violations(0)         | violations(1)       | violations(0)        | violations(1)       | violations(0)       | violations(1) | violations(0)          | violations(1)         | violations(0)         | violations(1)        | violations(0)         | violations(1)       | violations(0) | violations(1) | violations(0)          | violations(1)          | violations(0)        | violations(1)          | violations(0)         | violations(1)         | violations(0)         | violations(1)         | violations(0)         | violations(1)         | violations(0)         | violations(1)          | violations(0)         | violations(1)        | violations(0) | violations(1)         | violations(0)         | violations(1)         | violations(0)         | violations(1)        | violations(0)        | violations(1)        | violations(0)       | violations(1)       | violations(0)          | violations(1)        | violations(0)          | violations(1)         | violations(0)         | violations(1)      | violations(0)         | violations(1)        |
# +------------+-----------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+---------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------+---------------+---------------+------------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+--------------------+-----------------------+----------------------+
# | landuse(0) | 0.9998640010879913    | 0.9940711462450593   | 0.9987190435525192    | 0.9454545454545454  | 0.9724770642201835   | 0.5714285714285714  | 0.9491525423728814  | 0.25          | 0.9999439964157706     | 0.9985133795837463    | 0.9997132753512377    | 0.9940711462450593   | 0.9891696750902527    | 0.8421052631578947  | 0.88          | 0.25          | 1.9992802591067215e-05 | 0.00017241379310344826 | 3.65724317009838e-05 | 0.00010761945759793371 | 0.0005733944954128441 | 0.0009285051067780873 | 0.0009433962264150943 | 0.0035460992907801418 | 0.0007288629737609329 | 0.0010224948875255625 | 0.0002608242044861763 | 0.00025006251562890725 | 0.0012033694344163659 | 0.001226993865030675 | 0.00078125    | 0.0033003300330033004 | 0.0003885003885003885 | 0.0031645569620253164 | 0.0007168458781362007 | 0.002421307506053269 | 0.007936507936507936 | 0.041666666666666664 | 0.01282051282051282 | 0.08333333333333333 | 0.00011926058437686345 | 0.001694915254237288 | 0.00011779950524207798 | 0.0010559662090813093 | 0.0018450184501845018 | 0.0136986301369863 | 0.0019646365422396855 | 0.018518518518518517 |
# +------------+-----------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+---------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------+---------------+---------------+------------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+--------------------+-----------------------+----------------------+
# | landuse(1) | 4.533297066956798e-05 | 0.001976284584980237 | 0.0004269854824935952 | 0.01818181818181818 | 0.009174311926605505 | 0.14285714285714285 | 0.01694915254237288 | 0.25          | 1.8667861409796893e-05 | 0.0004955401387512388 | 9.557488292076843e-05 | 0.001976284584980237 | 0.0036101083032490976 | 0.05263157894736842 | 0.04          | 0.25          | 0.9897636850733735     | 0.9493103448275862     | 0.9219910031818016   | 0.7988592337494619     | 0.6702981651376146    | 0.6137418755803157    | 0.40849056603773587   | 0.2695035460992908    | 0.0007288629737609329 | 0.0010224948875255625 | 0.0002608242044861763 | 0.00025006251562890725 | 0.0012033694344163659 | 0.001226993865030675 | 0.00078125    | 0.0033003300330033004 | 0.9362859362859363    | 0.9335443037974683    | 0.7483870967741936    | 0.6537530266343826   | 0.4444444444444444   | 0.20833333333333334  | 0.2564102564102564  | 0.08333333333333333 | 0.00011926058437686345 | 0.001694915254237288 | 0.00011779950524207798 | 0.0010559662090813093 | 0.0018450184501845018 | 0.0136986301369863 | 0.0019646365422396855 | 0.018518518518518517 |
# +------------+-----------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+---------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------+---------------+---------------+------------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+--------------------+-----------------------+----------------------+
# | landuse(2) | 4.533297066956798e-05 | 0.001976284584980237 | 0.0004269854824935952 | 0.01818181818181818 | 0.009174311926605505 | 0.14285714285714285 | 0.01694915254237288 | 0.25          | 1.8667861409796893e-05 | 0.0004955401387512388 | 9.557488292076843e-05 | 0.001976284584980237 | 0.0036101083032490976 | 0.05263157894736842 | 0.04          | 0.25          | 1.9992802591067215e-05 | 0.00017241379310344826 | 3.65724317009838e-05 | 0.00010761945759793371 | 0.0005733944954128441 | 0.0009285051067780873 | 0.0009433962264150943 | 0.0035460992907801418 | 0.9329446064139941    | 0.9192229038854806    | 0.8458528951486698    | 0.8267066766691673     | 0.8002406738868832    | 0.7251533742331289   | 0.7609375     | 0.5016501650165016    | 0.06254856254856254   | 0.060126582278481014  | 0.24874551971326164   | 0.3365617433414044   | 0.5317460317460317   | 0.7083333333333334   | 0.7051282051282052  | 0.75                | 0.00011926058437686345 | 0.001694915254237288 | 0.00011779950524207798 | 0.0010559662090813093 | 0.0018450184501845018 | 0.0136986301369863 | 0.0019646365422396855 | 0.018518518518518517 |
# +------------+-----------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+---------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------+---------------+---------------+------------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+--------------------+-----------------------+----------------------+
# | landuse(3) | 4.533297066956798e-05 | 0.001976284584980237 | 0.0004269854824935952 | 0.01818181818181818 | 0.009174311926605505 | 0.14285714285714285 | 0.01694915254237288 | 0.25          | 1.8667861409796893e-05 | 0.0004955401387512388 | 9.557488292076843e-05 | 0.001976284584980237 | 0.0036101083032490976 | 0.05263157894736842 | 0.04          | 0.25          | 0.01019632932144428    | 0.0503448275862069     | 0.07793585195479648  | 0.20092552733534222    | 0.32855504587155965   | 0.38440111420612816   | 0.589622641509434     | 0.723404255319149     | 0.06559766763848396   | 0.0787321063394683    | 0.15362545644235784   | 0.1727931982995749     | 0.197352587244284     | 0.2723926380368098   | 0.2375        | 0.49174917491749176   | 0.000777000777000777  | 0.0031645569620253164 | 0.002150537634408602  | 0.007263922518159807 | 0.015873015873015872 | 0.041666666666666664 | 0.02564102564102564 | 0.08333333333333333 | 0.9996422182468694     | 0.9949152542372881   | 0.9996466014842738     | 0.996832101372756     | 0.9944649446494465    | 0.958904109589041  | 0.9941060903732809    | 0.9444444444444444   |
# +------------+-----------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+---------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------+---------------+---------------+------------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+----------------------+---------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+------------------------+----------------------+------------------------+-----------------------+-----------------------+--------------------+-----------------------+----------------------+
# (violations _|_ affordability_flag | residfar, subsidies_flag, bldgclass)
# {'unitsres': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'bldgclass': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'subsidies_flag': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'ownertype': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'residfar': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'yearbuilt': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'affordability_flag': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'violations': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}
# {'landuse': set(['unitsres', 'bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'affordability_flag', 'violations', 'landuse'])}

# %%
from collections import defaultdict
from pgmpy.inference import VariableElimination
def temp_predict(model,data):
    missing_variables = list(set(model.nodes()) - set(data.columns))
    pred_values = defaultdict(list)
    model_inference = VariableElimination(model)
    count = 0
    for index, data_point in data.iterrows():
        count = count+1
        if count %1000 == 1:
          print count
        states_dict = model_inference.map_query(variables=missing_variables, evidence=data_point.astype(int).to_dict())
        for k, v in states_dict.items():
            pred_values[k].append(v)
    return pd.DataFrame(pred_values, index=data.index)

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')
test_x = data18test.drop(columns=['violations'])
predicted_test = temp_predict(best_model, test_x)
print "Out of sample:",(data18test.loc[:,'violations']==predicted_test['violations']).mean()
# Out:
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 34001
# 35001
# 36001
# 37001
# 38001
# 39001
# 40001
# 41001
# 42001
# 43001
# 44001
# 45001
# 46001
# 47001
# 48001
# 49001
# 50001
# 51001
# 52001
# 53001
# 54001
# 55001
# 56001
# Out of sample: 0.8878739155785642

# %%
train_x = data18train.drop(columns=['violations'])
predicted_train = temp_predict(best_model, train_x)
print "In of sample:",(data18train.loc[:,'violations']==predicted_train['violations']).mean()

# %%
data18smaller = pd.read_csv("data15smaller_2.csv", low_memory = False, dtype = {'subsidies_flag':"int64"})

# %%
data18train, data18test = train_test_split(data18smaller,random_state=9,test_size=0.2)
hc = HillClimbSearch(data18train, scoring_method=BicScore(data18train))
best_model = hc.estimate()
print(best_model.edges())
# Out:
# [('bldgclass', 'subsidies_flag'), ('bldgclass', 'ownertype'), ('bldgclass', 'residfar'), ('bldgclass', 'yearbuilt'), ('bldgclass', 'unit_ratio'), ('bldgclass', 'violations'), ('residfar', 'violations'), ('yearbuilt', 'residfar'), ('yearbuilt', 'unit_ratio'), ('yearbuilt', 'subsidies_flag'), ('yearbuilt', 'ownertype'), ('unit_ratio', 'residfar'), ('unit_ratio', 'violations'), ('violations', 'subsidies_flag'), ('landuse', 'yearbuilt'), ('landuse', 'bldgclass')]

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')

for cpd in best_model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
    
print best_model.local_independencies('violations')

for thenode in best_model.nodes():
    print best_model.active_trail_nodes(thenode)
# Out:
# CPD of bldgclass:
# +--------------+-----------------------+------------------------+-----------------------+------------------------+
# | landuse      | landuse(0)            | landuse(1)             | landuse(2)            | landuse(3)             |
# +--------------+-----------------------+------------------------+-----------------------+------------------------+
# | bldgclass(0) | 0.2734740383050296    | 1.0661549123087584e-05 | 8.383635144198524e-05 | 3.505328098710039e-05  |
# +--------------+-----------------------+------------------------+-----------------------+------------------------+
# | bldgclass(1) | 0.7264825565623135    | 1.0661549123087584e-05 | 8.383635144198524e-05 | 3.505328098710039e-05  |
# +--------------+-----------------------+------------------------+-----------------------+------------------------+
# | bldgclass(2) | 1.085128316423417e-05 | 0.9571618956234341     | 8.383635144198524e-05 | 0.23366517106001122    |
# +--------------+-----------------------+------------------------+-----------------------+------------------------+
# | bldgclass(3) | 1.085128316423417e-05 | 1.0661549123087584e-05 | 0.9310865191146881    | 0.0802369601794728     |
# +--------------+-----------------------+------------------------+-----------------------+------------------------+
# | bldgclass(4) | 1.085128316423417e-05 | 0.04279545818007356    | 0.06857813547954393   | 0.00038558609085810434 |
# +--------------+-----------------------+------------------------+-----------------------+------------------------+
# | bldgclass(5) | 1.085128316423417e-05 | 1.0661549123087584e-05 | 8.383635144198524e-05 | 0.6856421761076836     |
# +--------------+-----------------------+------------------------+-----------------------+------------------------+
# CPD of subsidies_flag:
# +-------------------+------------------------+-----------------------+------------------------+------------------------+------------------------+---------------+----------------------+----------------------+---------------+----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------+---------------------+----------------------+--------------------+--------------------+---------------------+---------------------+---------------------+---------------------+-----------------------+------------------------+-----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+
# | bldgclass         | bldgclass(0)           | bldgclass(0)          | bldgclass(0)           | bldgclass(0)           | bldgclass(0)           | bldgclass(0)  | bldgclass(0)         | bldgclass(0)         | bldgclass(0)  | bldgclass(0)         | bldgclass(1)          | bldgclass(1)           | bldgclass(1)          | bldgclass(1)          | bldgclass(1)          | bldgclass(1)          | bldgclass(1)         | bldgclass(1)         | bldgclass(1)          | bldgclass(1)          | bldgclass(2)         | bldgclass(2)         | bldgclass(2)         | bldgclass(2)          | bldgclass(2)         | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)         | bldgclass(2)        | bldgclass(3)         | bldgclass(3)        | bldgclass(3)        | bldgclass(3)         | bldgclass(3)        | bldgclass(3)        | bldgclass(3)        | bldgclass(3)        | bldgclass(3)        | bldgclass(3)       | bldgclass(4)        | bldgclass(4)  | bldgclass(4)        | bldgclass(4)         | bldgclass(4)       | bldgclass(4)       | bldgclass(4)        | bldgclass(4)        | bldgclass(4)        | bldgclass(4)        | bldgclass(5)          | bldgclass(5)           | bldgclass(5)          | bldgclass(5)          | bldgclass(5)        | bldgclass(5)         | bldgclass(5)         | bldgclass(5)         | bldgclass(5)        | bldgclass(5)        |
# +-------------------+------------------------+-----------------------+------------------------+------------------------+------------------------+---------------+----------------------+----------------------+---------------+----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------+---------------------+----------------------+--------------------+--------------------+---------------------+---------------------+---------------------+---------------------+-----------------------+------------------------+-----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+
# | violations        | violations(0)          | violations(0)         | violations(0)          | violations(0)          | violations(0)          | violations(1) | violations(1)        | violations(1)        | violations(1) | violations(1)        | violations(0)         | violations(0)          | violations(0)         | violations(0)         | violations(0)         | violations(1)         | violations(1)        | violations(1)        | violations(1)         | violations(1)         | violations(0)        | violations(0)        | violations(0)        | violations(0)         | violations(0)        | violations(1)       | violations(1)       | violations(1)       | violations(1)        | violations(1)       | violations(0)        | violations(0)       | violations(0)       | violations(0)        | violations(0)       | violations(1)       | violations(1)       | violations(1)       | violations(1)       | violations(1)      | violations(0)       | violations(0) | violations(0)       | violations(0)        | violations(0)      | violations(1)      | violations(1)       | violations(1)       | violations(1)       | violations(1)       | violations(0)         | violations(0)          | violations(0)         | violations(0)         | violations(0)       | violations(1)        | violations(1)        | violations(1)        | violations(1)       | violations(1)       |
# +-------------------+------------------------+-----------------------+------------------------+------------------------+------------------------+---------------+----------------------+----------------------+---------------+----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------+---------------------+----------------------+--------------------+--------------------+---------------------+---------------------+---------------------+---------------------+-----------------------+------------------------+-----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+
# | yearbuilt         | yearbuilt(0)           | yearbuilt(1)          | yearbuilt(2)           | yearbuilt(3)           | yearbuilt(4)           | yearbuilt(0)  | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)  | yearbuilt(4)         | yearbuilt(0)          | yearbuilt(1)           | yearbuilt(2)          | yearbuilt(3)          | yearbuilt(4)          | yearbuilt(0)          | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)          | yearbuilt(4)          | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)          | yearbuilt(4)         | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)         | yearbuilt(4)        | yearbuilt(0)         | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)         | yearbuilt(4)        | yearbuilt(0)        | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)       | yearbuilt(0)        | yearbuilt(1)  | yearbuilt(2)        | yearbuilt(3)         | yearbuilt(4)       | yearbuilt(0)       | yearbuilt(1)        | yearbuilt(2)        | yearbuilt(3)        | yearbuilt(4)        | yearbuilt(0)          | yearbuilt(1)           | yearbuilt(2)          | yearbuilt(3)          | yearbuilt(4)        | yearbuilt(0)         | yearbuilt(1)         | yearbuilt(2)         | yearbuilt(3)        | yearbuilt(4)        |
# +-------------------+------------------------+-----------------------+------------------------+------------------------+------------------------+---------------+----------------------+----------------------+---------------+----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------+---------------------+----------------------+--------------------+--------------------+---------------------+---------------------+---------------------+---------------------+-----------------------+------------------------+-----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+
# | subsidies_flag(0) | 0.9998796920115496     | 0.999677731227844     | 0.9998219690226099     | 0.9997780736795384     | 0.9996782496782497     | 0.995         | 0.9852941176470589   | 0.9920634920634921   | 0.992         | 0.9821428571428571   | 0.999963661470257     | 0.9998338318378198     | 0.9999032601335011    | 0.9999165136082818    | 0.9998830546134955    | 0.9991023339317774    | 0.9951923076923077   | 0.9974226804123711   | 0.9977628635346756    | 0.9975490196078431    | 0.9922341350333237   | 0.9950663690825796   | 0.9945723684210527   | 0.9986759351208209    | 0.9782711757269279   | 0.8626089324618736  | 0.8828021248339973  | 0.91365257259297    | 0.9778206364513018   | 0.8450465707027942  | 0.9802440441603719   | 0.98562874251497    | 0.9887543252595156  | 0.9870669745958429   | 0.8749163879598663  | 0.7628541448058762  | 0.7748743718592965  | 0.9140271493212669  | 0.9049909801563439  | 0.4855072463768116 | 0.8925619834710744  | 0.90625       | 0.9437229437229437  | 0.9942857142857143   | 0.7810435931307794 | 0.7536231884057971 | 0.8823529411764706  | 0.5609756097560976  | 0.5384615384615384  | 0.6790606653620352  | 0.998346361996392     | 0.9995650282731623     | 0.999092911753272     | 0.9980769230769231    | 0.9754098360655737  | 0.9794303797468354   | 0.9732620320855615   | 0.9868247694334651   | 0.9714285714285714  | 0.8478260869565217  |
# +-------------------+------------------------+-----------------------+------------------------+------------------------+------------------------+---------------+----------------------+----------------------+---------------+----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------+---------------------+----------------------+--------------------+--------------------+---------------------+---------------------+---------------------+---------------------+-----------------------+------------------------+-----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+
# | subsidies_flag(1) | 0.00012030798845043312 | 0.0003222687721559781 | 0.00017803097739006588 | 0.00022192632046160674 | 0.00032175032175032174 | 0.005         | 0.014705882352941176 | 0.007936507936507936 | 0.008         | 0.017857142857142856 | 3.633852974308659e-05 | 0.00016616816218012627 | 9.673986649898423e-05 | 8.348639171814995e-05 | 0.0001169453865045024 | 0.0008976660682226212 | 0.004807692307692308 | 0.002577319587628866 | 0.0022371364653243847 | 0.0024509803921568627 | 0.007765864966676326 | 0.004933630917420416 | 0.005427631578947369 | 0.0013240648791790798 | 0.021728824273072062 | 0.13739106753812635 | 0.11719787516600266 | 0.08634742740703005 | 0.022179363548698167 | 0.15495342929720576 | 0.019755955839628123 | 0.01437125748502994 | 0.01124567474048443 | 0.012933025404157044 | 0.12508361204013377 | 0.23714585519412382 | 0.22512562814070353 | 0.08597285067873303 | 0.09500901984365605 | 0.5144927536231884 | 0.10743801652892562 | 0.09375       | 0.05627705627705628 | 0.005714285714285714 | 0.2189564068692206 | 0.2463768115942029 | 0.11764705882352941 | 0.43902439024390244 | 0.46153846153846156 | 0.32093933463796476 | 0.0016536380036079375 | 0.00043497172683775554 | 0.0009070882467280031 | 0.0019230769230769232 | 0.02459016393442623 | 0.020569620253164556 | 0.026737967914438502 | 0.013175230566534914 | 0.02857142857142857 | 0.15217391304347827 |
# +-------------------+------------------------+-----------------------+------------------------+------------------------+------------------------+---------------+----------------------+----------------------+---------------+----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+-----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------+---------------------+----------------------+--------------------+--------------------+---------------------+---------------------+---------------------+---------------------+-----------------------+------------------------+-----------------------+-----------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+
# CPD of ownertype:
# +--------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+-----------------------+-----------------------+
# | bldgclass    | bldgclass(0)           | bldgclass(0)           | bldgclass(0)           | bldgclass(0)          | bldgclass(0)          | bldgclass(1)           | bldgclass(1)           | bldgclass(1)          | bldgclass(1)          | bldgclass(1)           | bldgclass(2)          | bldgclass(2)          | bldgclass(2)          | bldgclass(2)           | bldgclass(2)           | bldgclass(3)          | bldgclass(3)          | bldgclass(3)          | bldgclass(3)           | bldgclass(3)          | bldgclass(4)          | bldgclass(4)         | bldgclass(4)          | bldgclass(4)         | bldgclass(4)          | bldgclass(5)           | bldgclass(5)          | bldgclass(5)           | bldgclass(5)          | bldgclass(5)          |
# +--------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+-----------------------+-----------------------+
# | yearbuilt    | yearbuilt(0)           | yearbuilt(1)           | yearbuilt(2)           | yearbuilt(3)          | yearbuilt(4)          | yearbuilt(0)           | yearbuilt(1)           | yearbuilt(2)          | yearbuilt(3)          | yearbuilt(4)           | yearbuilt(0)          | yearbuilt(1)          | yearbuilt(2)          | yearbuilt(3)           | yearbuilt(4)           | yearbuilt(0)          | yearbuilt(1)          | yearbuilt(2)          | yearbuilt(3)           | yearbuilt(4)          | yearbuilt(0)          | yearbuilt(1)         | yearbuilt(2)          | yearbuilt(3)         | yearbuilt(4)          | yearbuilt(0)           | yearbuilt(1)          | yearbuilt(2)           | yearbuilt(3)          | yearbuilt(4)          |
# +--------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+-----------------------+-----------------------+
# | ownertype(0) | 0.9913074121931164     | 0.9870744010088273     | 0.9874651810584958     | 0.9935233160621761    | 0.9949447077409163    | 0.9979045889501991     | 0.9971093624538301     | 0.9972962893902666    | 0.9971028488652824    | 0.9954241071428571     | 0.9912316330187553    | 0.9947943779281624    | 0.993052736049082     | 0.9912429378531074     | 0.9868478103772221     | 0.9641121495327103    | 0.9792463134898962    | 0.9448248086991542    | 0.7132410551057717     | 0.8192307692307692    | 0.9911111111111112    | 0.9512195121951219   | 0.8535031847133758    | 0.984251968503937    | 0.998587570621469     | 0.9945092656142759     | 0.9975874547647768    | 0.9970508434587708     | 0.987410071942446     | 0.9922978177150192    |
# +--------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+-----------------------+-----------------------+
# | ownertype(1) | 0.003758956889463174   | 0.0009457755359394704  | 0.002785515320334262   | 0.0019430051813471502 | 0.00315955766192733   | 0.0015366347698540198  | 0.0017665007226593866  | 0.0014917024053701287 | 0.0012071463061323032 | 0.0020089285714285712  | 0.0024847688448214073 | 0.0014749262536873156 | 0.0022104930752921007 | 0.001271186440677966   | 0.004046827576239341   | 0.018317757009345795  | 0.009284543965046422  | 0.003624647603705195  | 0.01802037085400888    | 0.0876923076923077    | 0.0044444444444444444 | 0.012195121951219513 | 0.0031847133757961785 | 0.003937007874015748 | 0.0002824858757062147 | 0.0035689773507206588  | 0.0008041817450743868 | 0.00212339270968503    | 0.007194244604316547  | 0.0038510911424903724 |
# +--------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+-----------------------+-----------------------+
# | ownertype(2) | 0.004111359097850347   | 0.011349306431273645   | 0.008182451253481894   | 0.004101899827288429  | 0.000631911532385466  | 0.0002793881399734581  | 0.0008029548739360848  | 0.0005593884020137983 | 0.0015290519877675841 | 0.002232142857142857   | 0.003440449169752718  | 0.001995488460871074  | 0.0030225109396851174 | 0.007062146892655367   | 0.008744038155802861   | 0.007102803738317757  | 0.009830693610049153  | 0.04993958920660491   | 0.2640376077304779     | 0.08076923076923077   | 0.0014814814814814814 | 0.012195121951219513 | 0.0031847133757961785 | 0.003937007874015748 | 0.0002824858757062147 | 0.00013726835964310226 | 0.0004020908725371934 | 0.00011796626164916834 | 0.0017985611510791368 | 0.0012836970474967907 |
# +--------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+-----------------------+-----------------------+
# | ownertype(3) | 0.0007048044167743451  | 0.00031525851197982345 | 0.001392757660167131   | 0.0002158894645941278 | 0.000315955766192733  | 0.00024446462247677586 | 0.00016059097478721696 | 0.0005593884020137983 | 8.047642040882022e-05 | 0.0002232142857142857  | 0.002819256958547366  | 0.001648446989415235  | 0.0016691478323634231 | 0.0002824858757062147  | 0.00028905911258852437 | 0.009345794392523364  | 0.0010922992900054614 | 0.0012082158679017317 | 0.00026116479498563595 | 0.011538461538461539  | 0.0014814814814814814 | 0.012195121951219513 | 0.13694267515923567   | 0.003937007874015748 | 0.0005649717514124294 | 0.0016472203157172271  | 0.0008041817450743868 | 0.0005898313082458417  | 0.0017985611510791368 | 0.0012836970474967907 |
# +--------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+-----------------------+-----------------------+
# | ownertype(4) | 0.00011746740279572419 | 0.00031525851197982345 | 0.00017409470752089137 | 0.0002158894645941278 | 0.0009478672985781991 | 3.492351749668226e-05  | 0.00016059097478721696 | 9.323140033563304e-05 | 8.047642040882022e-05 | 0.00011160714285714285 | 2.389200812328276e-05 | 8.676036786395974e-05 | 4.511210357738981e-05 | 0.00014124293785310735 | 7.226477814713109e-05  | 0.0011214953271028037 | 0.0005461496450027307 | 0.0004027386226339106 | 0.004439801514755811   | 0.0007692307692307692 | 0.0014814814814814814 | 0.012195121951219513 | 0.0031847133757961785 | 0.003937007874015748 | 0.0002824858757062147 | 0.00013726835964310226 | 0.0004020908725371934 | 0.00011796626164916834 | 0.0017985611510791368 | 0.0012836970474967907 |
# +--------------+------------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+-----------------------+-----------------------+-----------------------+------------------------+-----------------------+-----------------------+----------------------+-----------------------+----------------------+-----------------------+------------------------+-----------------------+------------------------+-----------------------+-----------------------+
# CPD of residfar:
# +-------------+---------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+--------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+-----------------------+----------------------+---------------------+----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+--------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------+---------------------+---------------------+---------------------+
# | bldgclass   | bldgclass(0)        | bldgclass(0)         | bldgclass(0)         | bldgclass(0)         | bldgclass(0)         | bldgclass(0)        | bldgclass(0)         | bldgclass(0)        | bldgclass(0)        | bldgclass(0)         | bldgclass(0)        | bldgclass(0)         | bldgclass(0)         | bldgclass(0)         | bldgclass(0)         | bldgclass(0)        | bldgclass(0)        | bldgclass(0)         | bldgclass(0)         | bldgclass(0)  | bldgclass(0)        | bldgclass(0)        | bldgclass(0)        | bldgclass(0)         | bldgclass(0)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)  | bldgclass(1)         | bldgclass(1)         | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)         | bldgclass(1)        | bldgclass(1)        | bldgclass(1)       | bldgclass(1)        | bldgclass(1)         | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(1)        | bldgclass(2)         | bldgclass(2)         | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)         | bldgclass(2)         | bldgclass(2)         | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)         | bldgclass(2)        | bldgclass(2)        | bldgclass(2)        | bldgclass(2)         | bldgclass(3)         | bldgclass(3)        | bldgclass(3)         | bldgclass(3)         | bldgclass(3)        | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)          | bldgclass(3)         | bldgclass(3)        | bldgclass(3)         | bldgclass(3)         | bldgclass(3)          | bldgclass(3)         | bldgclass(3)         | bldgclass(3)         | bldgclass(3)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)        | bldgclass(4)         | bldgclass(4)  | bldgclass(4)         | bldgclass(4)        | bldgclass(4)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)        | bldgclass(4)       | bldgclass(4)        | bldgclass(4)         | bldgclass(4)        | bldgclass(4)        | bldgclass(4)         | bldgclass(4)        | bldgclass(5)         | bldgclass(5)        | bldgclass(5)         | bldgclass(5)        | bldgclass(5)         | bldgclass(5)        | bldgclass(5)        | bldgclass(5)         | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)         | bldgclass(5)         | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        | bldgclass(5)  | bldgclass(5)        | bldgclass(5)        | bldgclass(5)        |
# +-------------+---------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+--------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+-----------------------+----------------------+---------------------+----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+--------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------+---------------------+---------------------+---------------------+
# | unit_ratio  | unit_ratio(0)       | unit_ratio(0)        | unit_ratio(0)        | unit_ratio(0)        | unit_ratio(0)        | unit_ratio(1)       | unit_ratio(1)        | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(1)        | unit_ratio(2)       | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(3)       | unit_ratio(3)       | unit_ratio(3)        | unit_ratio(3)        | unit_ratio(3) | unit_ratio(4)       | unit_ratio(4)       | unit_ratio(4)       | unit_ratio(4)        | unit_ratio(4)       | unit_ratio(0)       | unit_ratio(0)       | unit_ratio(0) | unit_ratio(0)        | unit_ratio(0)        | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(2)       | unit_ratio(2)       | unit_ratio(2)       | unit_ratio(2)        | unit_ratio(2)       | unit_ratio(3)       | unit_ratio(3)      | unit_ratio(3)       | unit_ratio(3)        | unit_ratio(3)       | unit_ratio(4)       | unit_ratio(4)       | unit_ratio(4)       | unit_ratio(4)       | unit_ratio(4)       | unit_ratio(0)        | unit_ratio(0)        | unit_ratio(0)       | unit_ratio(0)       | unit_ratio(0)       | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(2)       | unit_ratio(2)       | unit_ratio(2)       | unit_ratio(2)       | unit_ratio(2)        | unit_ratio(3)        | unit_ratio(3)        | unit_ratio(3)       | unit_ratio(3)       | unit_ratio(3)       | unit_ratio(4)        | unit_ratio(4)       | unit_ratio(4)       | unit_ratio(4)       | unit_ratio(4)        | unit_ratio(0)        | unit_ratio(0)       | unit_ratio(0)        | unit_ratio(0)        | unit_ratio(0)       | unit_ratio(1)        | unit_ratio(1)        | unit_ratio(1)        | unit_ratio(1)        | unit_ratio(1)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(3)         | unit_ratio(3)        | unit_ratio(3)       | unit_ratio(3)        | unit_ratio(3)        | unit_ratio(4)         | unit_ratio(4)        | unit_ratio(4)        | unit_ratio(4)        | unit_ratio(4)       | unit_ratio(0)        | unit_ratio(0)       | unit_ratio(0)        | unit_ratio(0)       | unit_ratio(0)       | unit_ratio(1)        | unit_ratio(1) | unit_ratio(1)        | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(2)        | unit_ratio(2)       | unit_ratio(2)        | unit_ratio(2)       | unit_ratio(2)       | unit_ratio(3)        | unit_ratio(3)       | unit_ratio(3)       | unit_ratio(3)      | unit_ratio(3)       | unit_ratio(4)        | unit_ratio(4)       | unit_ratio(4)       | unit_ratio(4)        | unit_ratio(4)       | unit_ratio(0)        | unit_ratio(0)       | unit_ratio(0)        | unit_ratio(0)       | unit_ratio(0)        | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(1)        | unit_ratio(1)       | unit_ratio(1)       | unit_ratio(2)       | unit_ratio(2)        | unit_ratio(2)        | unit_ratio(2)       | unit_ratio(2)       | unit_ratio(3)       | unit_ratio(3)       | unit_ratio(3)       | unit_ratio(3)       | unit_ratio(3)       | unit_ratio(4)       | unit_ratio(4) | unit_ratio(4)       | unit_ratio(4)       | unit_ratio(4)       |
# +-------------+---------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+--------------------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+-----------------------+----------------------+---------------------+----------------------+----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+--------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------+---------------------+---------------------+---------------------+
# ...
# +---------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+--------------------+----------------------+----------------------+---------------------+----------------------+--------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+---------------------+----------------------+--------------------+---------------------+--------------------+-------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+---------------------+--------------------+--------------------+----------------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+----------------------+--------------------+-------------------+---------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+----------------------+---------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+---------------+---------------------+----------------------+---------------------+---------------+---------------------+---------------------+---------------------+----------------------+--------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+--------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+----------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | violations(0) | 0.9745042492917847   | 0.9776223776223776   | 0.979957356076759    | 0.9798748980146859   | 0.9768258426966292   | 0.9583333333333334   | 0.9710982658959537   | 0.9694477085781433  | 0.979792463134899    | 0.9786571809693198 | 0.9761904761904762   | 0.9716312056737588   | 0.9600886917960089  | 0.9725714285714285   | 0.9734717416378316 | 0.9333333333333333  | 0.963855421686747   | 0.9772727272727273   | 0.979498861047836   | 0.9798339264531435   | 0.9523809523809523   | 0.9512742099898063  | 0.9631359056279184   | 0.964824120603015    | 0.9661129568106313  | 0.959543850122183    | 0.9664591283390239 | 0.9689944134078212  | 0.9605217988328184 | 0.967984934086629 | 0.965348552792499   | 0.9653333333333334   | 0.9644012944983819  | 0.9677662582469369  | 0.9684395090590298   | 0.9535637149028078  | 0.9524048096192385  | 0.9481803797468354   | 0.9558232931726908  | 0.9598591549295775  | 0.8171783373577095  | 0.8409854423292273 | 0.9159192825112108  | 0.9484240687679083  | 0.9174311926605505  | 0.8490461708598286 | 0.9037313432835821 | 0.9676198486122792   | 0.9614438063986874  | 0.9651741293532339  | 0.8674021648626145  | 0.9005457359289729  | 0.9386406092829429   | 0.937809576224546   | 0.9499404052443385   | 0.6994786875191659 | 0.712202823179792 | 0.8041384231180878  | 0.8651434940094734  | 0.8956649522409993  | 0.6867469879518072 | 0.6530612244897959 | 0.6721311475409836  | 0.7567567567567568  | 0.9634146341463414   | 0.52          | 0.5170731707317073  | 0.5833333333333334 | 0.7209302325581395  | 0.8571428571428571  | 0.5794979079497908 | 0.5207667731629393 | 0.5333333333333333 | 0.6144578313253012 | 0.782608695652174   | 0.6125119693584424 | 0.4606351748065119 | 0.4249329758713137 | 0.5492565055762082 | 0.8993135011441648  | 0.6875        | 0.926829268292683   | 0.9819819819819819   | 0.9285714285714286  | 0.875         | 0.9072164948453608  | 0.8333333333333334  | 0.9159663865546218  | 0.9912280701754386   | 0.7536231884057971 | 0.8571428571428571  | 0.8419753086419753 | 0.9429223744292238  | 0.9300699300699301  | 0.8097560975609757 | 0.6370023419203747 | 0.6998191681735986  | 0.9003215434083601  | 0.8482142857142857  | 0.9272727272727272  | 0.9170792079207921  | 0.9228915662650602  | 0.9517241379310345  | 0.9313725490196079  | 0.9463087248322147   | 0.9491869918699187 | 0.9381443298969072   | 0.9714285714285714  | 0.9156626506024096  | 0.9454545454545454  | 0.9226821758467328 | 0.9371877230549608  | 0.9460400348128808   | 0.9463519313304721 | 0.9457013574660633  | 0.8774752475247525  | 0.9024580569644948  | 0.9275296262534184  | 0.8973384030418251  | 0.9236842105263158  |
# +---------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+--------------------+----------------------+----------------------+---------------------+----------------------+--------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+---------------------+----------------------+--------------------+---------------------+--------------------+-------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+---------------------+--------------------+--------------------+----------------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+----------------------+--------------------+-------------------+---------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+----------------------+---------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+---------------+---------------------+----------------------+---------------------+---------------+---------------------+---------------------+---------------------+----------------------+--------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+--------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+----------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# | violations(1) | 0.025495750708215296 | 0.022377622377622378 | 0.020042643923240937 | 0.020125101985314114 | 0.023174157303370788 | 0.041666666666666664 | 0.028901734104046242 | 0.03055229142185664 | 0.020207536865101038 | 0.0213428190306803 | 0.023809523809523808 | 0.028368794326241134 | 0.03991130820399113 | 0.027428571428571427 | 0.0265282583621684 | 0.06666666666666667 | 0.03614457831325301 | 0.022727272727272728 | 0.02050113895216401 | 0.020166073546856466 | 0.047619047619047616 | 0.04872579001019368 | 0.036864094372081595 | 0.035175879396984924 | 0.03388704318936877 | 0.040456149877816996 | 0.0335408716609761 | 0.03100558659217877 | 0.0394782011671816 | 0.032015065913371 | 0.03465144720750102 | 0.034666666666666665 | 0.03559870550161812 | 0.03223374175306315 | 0.031560490940970194 | 0.04643628509719223 | 0.04759519038076152 | 0.051819620253164556 | 0.04417670682730924 | 0.04014084507042254 | 0.18282166264229044 | 0.1590145576707727 | 0.08408071748878924 | 0.05157593123209169 | 0.08256880733944955 | 0.1509538291401714 | 0.0962686567164179 | 0.032380151387720775 | 0.03855619360131255 | 0.03482587064676617 | 0.13259783513738552 | 0.09945426407102713 | 0.061359390717057045 | 0.06219042377545404 | 0.050059594755661505 | 0.3005213124808341 | 0.287797176820208 | 0.19586157688191225 | 0.13485650599052662 | 0.10433504775900074 | 0.3132530120481928 | 0.3469387755102041 | 0.32786885245901637 | 0.24324324324324326 | 0.036585365853658534 | 0.48          | 0.48292682926829267 | 0.4166666666666667 | 0.27906976744186046 | 0.14285714285714285 | 0.4205020920502092 | 0.4792332268370607 | 0.4666666666666667 | 0.3855421686746988 | 0.21739130434782608 | 0.3874880306415576 | 0.5393648251934882 | 0.5750670241286864 | 0.4507434944237918 | 0.10068649885583524 | 0.3125        | 0.07317073170731707 | 0.018018018018018018 | 0.07142857142857142 | 0.125         | 0.09278350515463918 | 0.16666666666666666 | 0.08403361344537816 | 0.008771929824561403 | 0.2463768115942029 | 0.14285714285714285 | 0.1580246913580247 | 0.05707762557077625 | 0.06993006993006994 | 0.1902439024390244 | 0.3629976580796253 | 0.30018083182640143 | 0.09967845659163987 | 0.15178571428571427 | 0.07272727272727272 | 0.08292079207920793 | 0.07710843373493977 | 0.04827586206896552 | 0.06862745098039216 | 0.053691275167785234 | 0.0508130081300813 | 0.061855670103092786 | 0.02857142857142857 | 0.08433734939759036 | 0.05454545454545454 | 0.0773178241532672 | 0.06281227694503926 | 0.053959965187119235 | 0.0536480686695279 | 0.05429864253393665 | 0.12252475247524752 | 0.09754194303550527 | 0.07247037374658159 | 0.10266159695817491 | 0.07631578947368421 |
# +---------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+---------------------+----------------------+--------------------+----------------------+----------------------+---------------------+----------------------+--------------------+---------------------+---------------------+----------------------+---------------------+----------------------+----------------------+---------------------+----------------------+----------------------+---------------------+----------------------+--------------------+---------------------+--------------------+-------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+---------------------+---------------------+--------------------+--------------------+----------------------+---------------------+---------------------+---------------------+---------------------+----------------------+---------------------+----------------------+--------------------+-------------------+---------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+----------------------+---------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+---------------------+---------------+---------------------+----------------------+---------------------+---------------+---------------------+---------------------+---------------------+----------------------+--------------------+---------------------+--------------------+---------------------+---------------------+--------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+----------------------+--------------------+----------------------+---------------------+---------------------+---------------------+--------------------+---------------------+----------------------+--------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+
# CPD of landuse:
# +------------+-----------+
# | landuse(0) | 0.407048  |
# +------------+-----------+
# | landuse(1) | 0.414292  |
# +------------+-----------+
# | landuse(2) | 0.0526667 |
# +------------+-----------+
# | landuse(3) | 0.125993  |
# +------------+-----------+
# (violations _|_ ownertype, landuse, yearbuilt | residfar, unit_ratio, bldgclass)
# {'bldgclass': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'subsidies_flag': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'ownertype': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'residfar': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'yearbuilt': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'unit_ratio': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'violations': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}
# {'landuse': set(['bldgclass', 'subsidies_flag', 'ownertype', 'residfar', 'yearbuilt', 'unit_ratio', 'violations', 'landuse'])}

# %%
best_model.fit(data18train, estimator=BayesianEstimator, prior_type='K2')
test_x = data18test.drop(columns=['violations'])
predicted_test = temp_predict(best_model, test_x)
print "Out of sample:",(data18test.loc[:,'violations']==predicted_test['violations']).mean()
# Out:
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 34001
# 35001
# 36001
# 37001
# 38001
# 39001
# 40001
# 41001
# 42001
# 43001
# 44001
# 45001
# 46001
# 47001
# 48001
# 49001
# 50001
# 51001
# 52001
# 53001
# 54001
# 55001
# 56001
# Out of sample: 0.8882076471835465
